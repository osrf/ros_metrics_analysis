# %%
#https://pygithub.readthedocs.io/en/stable/introduction.html
from github import Github
# Authentication is defined via github.Auth
from github import Auth
from tqdm.notebook import trange, tqdm
import pandas as pd
import numpy as np
import json 
from datetime import datetime, date
from collections import Counter
import plotly.express as px
import time
import pickle
intrinsic_people = ["@aaronchongth","@akash-roboticist","@andreasBihlmaier","@arjo129","@audrow","@azeey","@damon-oss","@faximan","@jennuine","@koonpeng","@kscottz","@luca-della-vedova","@marcoag","@mbordignon-intrinsic","@methylDragon","@mjcarroll","@mjeronimo","@mxgrey","@nuclearsandwich-ai","@quarkytale","@scpeters","@sloretz","@tfoote","@udaya2899","@xiyuoh","@Yadunund"]

# %%
# Grab the access token
with open('./tokens.json',"r") as json_data:
    tokens = json.loads(json_data.read())
    json_data.close()

auth = Auth.Token(tokens["Github"])

# Public Web Github
gh = Github(auth=auth)

# %%
org = gh.get_organization("ros2")
repos = org.get_repos()

# %%
def extract_contributions(gh, repo_name, start_date, end_date):
# Get github repo level stats for two date ranges
    repo = gh.get_repo(repo_name)
    prs = repo.get_pulls(state='closed', sort='created')
    year = []
    results = {}
    for pr in prs:
        if start_date < pr.closed_at.date() < end_date:
            year.append(pr)
    results["repo"] = repo_name
    results["prs"] = year
    results["start_date"] = start_date    
    results["end_date"] = end_date    
    results["users"] = []
    results["handles"] = []
    results["add"] = 0
    results["del"] = 0 
    results["comments"] = 0
    results["files"] = 0
    
    for pr in year:
        results["users"].append(pr.user.name)
        results["handles"].append(pr.user.login)
        results["files"] += pr.changed_files 
        results["del"] += pr.deletions
        results["add"] += pr.additions
        results["comments"] += pr.review_comments

    results["total_prs"] = len(prs)
    results["total_users"] = len(set(results["users"]))

    return results

# %%
# Create a list of github repos for an org
full_repo_list = []
i = 0
has_repos = True
while has_repos:
    next_repos = repos.get_page(i)
    if len(next_repos) > 0:
        i += 1
        full_repo_list += next_repos
    else:
        has_repos = False
        
print(full_repo_list)
print(len(full_repo_list))
# Out:
# [Repository(full_name="ros2/design"), Repository(full_name="ros2/rosidl"), Repository(full_name="ros2/examples"), Repository(full_name="ros2/rosidl_dds"), Repository(full_name="ros2/rmw"), Repository(full_name="ros2/rmw_connext"), Repository(full_name="ros2/rclcpp"), Repository(full_name="ros2/rmw_opensplice"), Repository(full_name="ros2/ros2_embedded_freertos"), Repository(full_name="ros2/ros2_embedded_sublime"), Repository(full_name="ros2/ros2_embedded_riot"), Repository(full_name="ros2/ros2_embedded_nuttx"), Repository(full_name="ros2/stlink"), Repository(full_name="ros2/tinq-core"), Repository(full_name="ros2/ros_core_documentation"), Repository(full_name="ros2/freertps"), Repository(full_name="ros2/rclc"), Repository(full_name="ros2/rcl"), Repository(full_name="ros2/ros2"), Repository(full_name="ros2/launch"), Repository(full_name="ros2/rmw_implementation"), Repository(full_name="ros2/rcl_interfaces"), Repository(full_name="ros2/system_tests"), Repository(full_name="ros2/rmw_fastrtps"), Repository(full_name="ros2/common_interfaces"), Repository(full_name="ros2/ros1_bridge"), Repository(full_name="ros2/realtime_support"), Repository(full_name="ros2/demos"), Repository(full_name="ros2/rmw_freertps"), Repository(full_name="ros2/ros2.github.io"), Repository(full_name="ros2/poco_vendor"), Repository(full_name="ros2/rclpy"), Repository(full_name="ros2/tlsf"), Repository(full_name="ros2/turtlebot2_demo"), Repository(full_name="ros2/ros_astra_camera"), Repository(full_name="ros2/ci"), Repository(full_name="ros2/cookbook"), Repository(full_name="ros2/rosidl_typesupport"), Repository(full_name="ros2/tutorials"), Repository(full_name="ros2/sros2"), Repository(full_name="ros2/ament_cmake_ros"), Repository(full_name="ros2/rcutils"), Repository(full_name="ros2/joystick_drivers_from_scratch"), Repository(full_name="ros2/ros2doc"), Repository(full_name="ros2/navigation"), Repository(full_name="ros2/robot_model"), Repository(full_name="ros2/robot_state_publisher"), Repository(full_name="ros2/orocos_kinematics_dynamics"), Repository(full_name="ros2/tinyxml_vendor"), Repository(full_name="ros2/urdfdom"), Repository(full_name="ros2/urdfdom_headers"), Repository(full_name="ros2/geometry2"), Repository(full_name="ros2/cartographer_ros"), Repository(full_name="ros2/choco-packages"), Repository(full_name="ros2/build_farmer"), Repository(full_name="ros2/vision_opencv"), Repository(full_name="ros2/pcl_conversions"), Repository(full_name="ros2/example_interfaces"), Repository(full_name="ros2/rosdistro"), Repository(full_name="ros2/ros_buildfarm_config"), Repository(full_name="ros2/ros_workspace"), Repository(full_name="ros2/joystick_drivers"), Repository(full_name="ros2/ceres-solver"), Repository(full_name="ros2/cartographer"), Repository(full_name="ros2/depthimage_to_laserscan"), Repository(full_name="ros2/teleop_twist_joy"), Repository(full_name="ros2/ros2cli"), Repository(full_name="ros2/teleop_twist_keyboard"), Repository(full_name="ros2/console_bridge"), Repository(full_name="ros2/docs.ros2.org"), Repository(full_name="ros2/rviz"), Repository(full_name="ros2/kdl_parser"), Repository(full_name="ros2/urdf"), Repository(full_name="ros2/tinyxml2_vendor"), Repository(full_name="ros2/rosbag2"), Repository(full_name="ros2/libyaml_vendor"), Repository(full_name="ros2/rosidl_typesupport_connext"), Repository(full_name="ros2/rosidl_typesupport_opensplice"), Repository(full_name="ros2/rosidl_python"), Repository(full_name="ros2/rosidl_defaults"), Repository(full_name="ros2/console_bridge_vendor"), Repository(full_name="ros2/rmw_cyclonedds"), Repository(full_name="ros2/message_filters"), Repository(full_name="ros2/variants"), Repository(full_name="ros2/rmw_dps"), Repository(full_name="ros2/rosidl_typesupport_fastrtps"), Repository(full_name="ros2/ros2_documentation"), Repository(full_name="ros2/yaml_cpp_vendor"), Repository(full_name="ros2/performance_test"), Repository(full_name="ros2/unique_identifier_msgs"), Repository(full_name="ros2/rcl_logging"), Re ...
# 138

# %%
this_year_start = date(2024, 1, 1)
this_year_end = date(2024, 12, 31)
this_year = 2024
last_year_start = date(2023, 1, 1)
last_year_end = date(2023, 12, 31)
last_year = 2023
full_org_results = {}
fname = 'github_stats_2024.pkl'
for repo in full_repo_list:
    print("Extracting data for {0} from {1} to {2}".format(repo.full_name,this_year_start,this_year_end))
    this_year_results = extract_contributions(gh, repo.full_name, this_year_start, this_year_end)
    print("Extracting data for {0} from {1} to {2}".format(repo.full_name,last_year_start,last_year_end))
    last_year_results = extract_contributions(gh, repo.full_name, last_year_start, last_year_end)
    full_org_results[repo.name] = {}
    full_org_results[repo.name][this_year] = this_year_results
    full_org_results[repo.name][last_year] = last_year_results
    with open(fname,"wb") as file:
        pickle.dump(full_org_results, file)
        print("Wrote: {0}".format(fname))
    print("-----------------------------")
# Out:
# Extracting data for ros2/design from 2024-01-01 to 2024-12-31
# Extracting data for ros2/design from 2023-01-01 to 2023-12-31
# Wrote: github_stats_2024.pkl
# -----------------------------
# Extracting data for ros2/rosidl from 2024-01-01 to 2024-12-31
# Extracting data for ros2/rosidl from 2023-01-01 to 2023-12-31
# Wrote: github_stats_2024.pkl
# -----------------------------
# Extracting data for ros2/examples from 2024-01-01 to 2024-12-31
# Extracting data for ros2/examples from 2023-01-01 to 2023-12-31
# Wrote: github_stats_2024.pkl
# -----------------------------
# Extracting data for ros2/rosidl_dds from 2024-01-01 to 2024-12-31
# Extracting data for ros2/rosidl_dds from 2023-01-01 to 2023-12-31
# Wrote: github_stats_2024.pkl
# -----------------------------
# Extracting data for ros2/rmw from 2024-01-01 to 2024-12-31
# Extracting data for ros2/rmw from 2023-01-01 to 2023-12-31
# Wrote: github_stats_2024.pkl
# -----------------------------
# Extracting data for ros2/rmw_connext from 2024-01-01 to 2024-12-31
# Extracting data for ros2/rmw_connext from 2023-01-01 to 2023-12-31
# Wrote: github_stats_2024.pkl
# -----------------------------
# Extracting data for ros2/rclcpp from 2024-01-01 to 2024-12-31
# Extracting data for ros2/rclcpp from 2023-01-01 to 2023-12-31
# Wrote: github_stats_2024.pkl
# -----------------------------
# Extracting data for ros2/rmw_opensplice from 2024-01-01 to 2024-12-31
# Extracting data for ros2/rmw_opensplice from 2023-01-01 to 2023-12-31
# Wrote: github_stats_2024.pkl
# -----------------------------
# Extracting data for ros2/ros2_embedded_freertos from 2024-01-01 to 2024-12-31
# Extracting data for ros2/ros2_embedded_freertos from 2023-01-01 to 2023-12-31
# Wrote: github_stats_2024.pkl
# -----------------------------
# Extracting data for ros2/ros2_embedded_sublime from 2024-01-01 to 2024-12-31
# Extracting data for ros2/ros2_embedded_sublime from 2023-01-01 to 2023-12-31
# Wrote: github_stats_2024.pkl
# -----------------------------
# Extracting data for ros2/ros2_embedded_riot from 2024-01-01 to 2024-12-31
# Extracting data for ros2/ros2_embedded_riot from 2023-01-01 to 2023-12-31
# Wrote: github_stats_2024.pkl
# -----------------------------
# Extracting data for ros2/ros2_embedded_nuttx from 2024-01-01 to 2024-12-31
# Extracting data for ros2/ros2_embedded_nuttx from 2023-01-01 to 2023-12-31
# Wrote: github_stats_2024.pkl
# -----------------------------
# Extracting data for ros2/stlink from 2024-01-01 to 2024-12-31
# Extracting data for ros2/stlink from 2023-01-01 to 2023-12-31
# Wrote: github_stats_2024.pkl
# -----------------------------
# Extracting data for ros2/tinq-core from 2024-01-01 to 2024-12-31
# Extracting data for ros2/tinq-core from 2023-01-01 to 2023-12-31
# Wrote: github_stats_2024.pkl
# -----------------------------
# Extracting data for ros2/ros_core_documentation from 2024-01-01 to 2024-12-31
# Extracting data for ros2/ros_core_documentation from 2023-01-01 to 2023-12-31
# Wrote: github_stats_2024.pkl
# -----------------------------
# Extracting data for ros2/freertps from 2024-01-01 to 2024-12-31
# Extracting data for ros2/freertps from 2023-01-01 to 2023-12-31
# Wrote: github_stats_2024.pkl
# -----------------------------
# Extracting data for ros2/rclc from 2024-01-01 to 2024-12-31
# Extracting data for ros2/rclc from 2023-01-01 to 2023-12-31
# Wrote: github_stats_2024.pkl
# -----------------------------
# Extracting data for ros2/rcl from 2024-01-01 to 2024-12-31
# Extracting data for ros2/rcl from 2023-01-01 to 2023-12-31
# Wrote: github_stats_2024.pkl
# -----------------------------
# Extracting data for ros2/ros2 from 2024-01-01 to 2024-12-31
# Extracting data for ros2/ros2 from 2023-01-01 to 2023-12-31
# Wrote: github_stats_2024.pkl
# -----------------------------
# Extracting data for ros2/launch from 2024-01-01 to 2024-12-31
# Extracting data for ros2/launch from 2023-01-01 to 2023-12-31
# Wrote: github_stats_2024.pkl
# -----------------------------
# Extracting data for ros2/rmw_implementation from 2024-01-01 to 2024-12-31
# Extracting data for ros2/rmw_implementation from 2023-01-01 to 2023-12-31
# Wrote: github_stats_2024.pkl
# -----------------------------
# Extracting data for ros2/rcl_interfaces from 2024-01-01 to 2024-12-31
# Extracting data for ros2/rcl_interfaces from 2023-01-01 to 2023-12-31
# Wrote: github_stats_2024.pkl
# -----------------------------
# Extracting data for ros2/system_tests from 2024-01-01 to 2024-12-31
# Extracting data for ros2/system_tests from 2023-01-01 to 2023-12-31
# Wrote: github_stats_2024.pkl
# -----------------------------
# Extracting data for ros2/rmw_fastrtps from 2024-01-01 to 2024-12-31
# Extracting data for ros2/rmw_fastrtps from 2023-01-01 to 2023-12-31
# Wrote: github_stats_2024.pkl
# -----------------------------
# Extracting data for ros2/common_interfaces from 2024-01-01 to 2024-12-31
# Extracting data for ros2/common_interfaces from 2023-01-01 to 2023-12-31
# Wrote: github_stats_2024.pkl
# -----------------------------
# Extracting data for ros2/ros1_bridge from 2024-01-01 to 2024-12-31
# Extracting data for ros2/ros1_bridge from 2023-01-01 to 2023-12-31
# Wrote: github_stats_2024.pkl
# -----------------------------
# Extracting data for ros2/realtime_support from 2024-01-01 to 2024-12-31
# Extracting data for ros2/realtime_support from 2023-01-01 to 2023-12-31
# Wrote: github_stats_2024.pkl
# -----------------------------
# Extracting data for ros2/demos from 2024-01-01 to 2024-12-31
# Extracting data for ros2/demos from 2023-01-01 to 2023-12-31
# Wrote: github_stats_2024.pkl
# -----------------------------
# Extracting data for ros2/rmw_freertps from 2024-01-01 to 2024-12-31
# Extracting data for ros2/rmw_freertps from 2023-01-01 to 2023-12-31
# Wrote: github_stats_2024.pkl
# -----------------------------
# Extracting data for ros2/ros2.github.io from 2024-01-01 to 2024-12-31
# Extracting data for ros2/ros2.github.io from 2023-01-01 to 2023-12-31
# Wrote: github_stats_2024.pkl
# -----------------------------
# Extracting data for ros2/poco_vendor from 2024-01-01 to 2024-12-31
# Extracting data for ros2/poco_vendor from 2023-01-01 to 2023-12-31
# Wrote: github_stats_2024.pkl
# -----------------------------
# Extracting data for ros2/rclpy from 2024-01-01 to 2024-12-31
# Extracting data for ros2/rclpy from 2023-01-01 to 2023-12-31
# Wrote: github_stats_2024.pkl
# -----------------------------
# Extracting data for ros2/tlsf from 2024-01-01 to 2024-12-31
# Extracting data for ros2/tlsf from 2023-01-01 to 2023-12-31
# Wrote: github_stats_2024.pkl
# -----------------------------
# Extracting data for ros2/turtlebot2_demo from 2024-01-01 to 2024-12-31
# Extracting data for ros2/turtlebot2_demo from 2023-01-01 to 2023-12-31
# Wrote: github_stats_2024.pkl
# -----------------------------
# Extracting data for ros2/ros_astra_camera from 2024-01-01 to 2024-12-31
# Extracting data for ros2/ros_astra_camera from 2023-01-01 to 2023-12-31
# Wrote: github_stats_2024.pkl
# -----------------------------
# Extracting data for ros2/ci from 2024-01-01 to 2024-12-31
# Extracting data for ros2/ci from 2023-01-01 to 2023-12-31
# Wrote: github_stats_2024.pkl
# -----------------------------
# Extracting data for ros2/cookbook from 2024-01-01 to 2024-12-31
# Extracting data for ros2/cookbook from 2023-01-01 to 2023-12-31
# Wrote: github_stats_2024.pkl
# -----------------------------
# Extracting data for ros2/rosidl_typesupport from 2024-01-01 to 2024-12-31
# Extracting data for ros2/rosidl_typesupport from 2023-01-01 to 2023-12-31
# Wrote: github_stats_2024.pkl
# -----------------------------
# Extracting data for ros2/tutorials from 2024-01-01 to 2024-12-31
# Extracting data for ros2/tutorials from 2023-01-01 to 2023-12-31
# Wrote: github_stats_2024.pkl
# -----------------------------
# Extracting data for ros2/sros2 from 2024-01-01 to 2024-12-31
# Extracting data for ros2/sros2 from 2023-01-01 to 2023-12-31
# Wrote: github_stats_2024.pkl
# -----------------------------
# Extracting data for ros2/ament_cmake_ros from 2024-01-01 to 2024-12-31
# Extracting data for ros2/ament_cmake_ros from 2023-01-01 to 2023-12-31
# Wrote: github_stats_2024.pkl
# -----------------------------
# Extracting data for ros2/rcutils from 2024-01-01 to 2024-12-31
# Extracting data for ros2/rcutils from 2023-01-01 to 2023-12-31
# Wrote: github_stats_2024.pkl
# -----------------------------
# Extracting data for ros2/joystick_drivers_from_scratch from 2024-01-01 to 2024-12-31
# Extracting data for ros2/joystick_drivers_from_scratch from 2023-01-01 to 2023-12-31
# Wrote: github_stats_2024.pkl
# -----------------------------
# Extracting data for ros2/ros2doc from 2024-01-01 to 2024-12-31
# Extracting data for ros2/ros2doc from 2023-01-01 to 2023-12-31
# Wrote: github_stats_2024.pkl
# -----------------------------
# Extracting data for ros2/navigation from 2024-01-01 to 2024-12-31
# Extracting data for ros2/navigation from 2023-01-01 to 2023-12-31
# Wrote: github_stats_2024.pkl
# -----------------------------
# Extracting data for ros2/robot_model from 2024-01-01 to 2024-12-31
# Extracting data for ros2/robot_model from 2023-01-01 to 2023-12-31
# Wrote: github_stats_2024.pkl
# -----------------------------
# Extracting data for ros2/robot_state_publisher from 2024-01-01 to 2024-12-31
# Extracting data for ros2/robot_state_publisher from 2023-01-01 to 2023-12-31
# Wrote: github_stats_2024.pkl
# -----------------------------
# Extracting data for ros2/orocos_kinematics_dynamics from 2024-01-01 to 2024-12-31
# Extracting data for ros2/orocos_kinematics_dynamics from 2023-01-01 to 2023-12-31
# Wrote: github_stats_2024.pkl
# -----------------------------
# Extracting data for ros2/tinyxml_vendor from 2024-01-01 to 2024-12-31
# Extracting data for ros2/tinyxml_vendor from 2023-01-01 to 2023-12-31
# Wrote: github_stats_2024.pkl
# -----------------------------
# Extracting data for ros2/urdfdom from 2024-01-01 to 2024-12-31
# Extracting data for ros2/urdfdom from 2023-01-01 to 2023-12-31
# Wrote: github_stats_2024.pkl
# -----------------------------
# Extracting data for ros2/urdfdom_headers from 2024-01-01 to 2024-12-31
# Extracting data for ros2/urdfdom_headers from 2023-01-01 to 2023-12-31
# Wrote: github_stats_2024.pkl
# -----------------------------
# Extracting data for ros2/geometry2 from 2024-01-01 to 2024-12-31
# Extracting data for ros2/geometry2 from 2023-01-01 to 2023-12-31
# Wrote: github_stats_2024.pkl
# -----------------------------
# Extracting data for ros2/cartographer_ros from 2024-01-01 to 2024-12-31
# Extracting data for ros2/cartographer_ros from 2023-01-01 to 2023-12-31
# Wrote: github_stats_2024.pkl
# -----------------------------
# Extracting data for ros2/choco-packages from 2024-01-01 to 2024-12-31
# Extracting data for ros2/choco-packages from 2023-01-01 to 2023-12-31
# Wrote: github_stats_2024.pkl
# -----------------------------
# Extracting data for ros2/build_farmer from 2024-01-01 to 2024-12-31
# Extracting data for ros2/build_farmer from 2023-01-01 to 2023-12-31
# Wrote: github_stats_2024.pkl
# -----------------------------
# Extracting data for ros2/vision_opencv from 2024-01-01 to 2024-12-31
# Extracting data for ros2/vision_opencv from 2023-01-01 to 2023-12-31
# Wrote: github_stats_2024.pkl
# -----------------------------
# Extracting data for ros2/pcl_conversions from 2024-01-01 to 2024-12-31
# Extracting data for ros2/pcl_conversions from 2023-01-01 to 2023-12-31
# Wrote: github_stats_2024.pkl
# -----------------------------
# Extracting data for ros2/example_interfaces from 2024-01-01 to 2024-12-31
# Extracting data for ros2/example_interfaces from 2023-01-01 to 2023-12-31
# Wrote: github_stats_2024.pkl
# -----------------------------
# Extracting data for ros2/rosdistro from 2024-01-01 to 2024-12-31
# Extracting data for ros2/rosdistro from 2023-01-01 to 2023-12-31
# Wrote: github_stats_2024.pkl
# -----------------------------
# Extracting data for ros2/ros_buildfarm_config from 2024-01-01 to 2024-12-31
# Extracting data for ros2/ros_buildfarm_config from 2023-01-01 to 2023-12-31
# Wrote: github_stats_2024.pkl
# -----------------------------
# Extracting data for ros2/ros_workspace from 2024-01-01 to 2024-12-31
# Extracting data for ros2/ros_workspace from 2023-01-01 to 2023-12-31
# Wrote: github_stats_2024.pkl
# -----------------------------
# Extracting data for ros2/joystick_drivers from 2024-01-01 to 2024-12-31
# Extracting data for ros2/joystick_drivers from 2023-01-01 to 2023-12-31
# Wrote: github_stats_2024.pkl
# -----------------------------
# Extracting data for ros2/ceres-solver from 2024-01-01 to 2024-12-31
# Extracting data for ros2/ceres-solver from 2023-01-01 to 2023-12-31
# Wrote: github_stats_2024.pkl
# -----------------------------
# Extracting data for ros2/cartographer from 2024-01-01 to 2024-12-31
# Extracting data for ros2/cartographer from 2023-01-01 to 2023-12-31
# Wrote: github_stats_2024.pkl
# -----------------------------
# Extracting data for ros2/depthimage_to_laserscan from 2024-01-01 to 2024-12-31
# Extracting data for ros2/depthimage_to_laserscan from 2023-01-01 to 2023-12-31
# Wrote: github_stats_2024.pkl
# -----------------------------
# Extracting data for ros2/teleop_twist_joy from 2024-01-01 to 2024-12-31
# Extracting data for ros2/teleop_twist_joy from 2023-01-01 to 2023-12-31
# Wrote: github_stats_2024.pkl
# -----------------------------
# Extracting data for ros2/ros2cli from 2024-01-01 to 2024-12-31
# Extracting data for ros2/ros2cli from 2023-01-01 to 2023-12-31
# Wrote: github_stats_2024.pkl
# -----------------------------
# Extracting data for ros2/teleop_twist_keyboard from 2024-01-01 to 2024-12-31
# Extracting data for ros2/teleop_twist_keyboard from 2023-01-01 to 2023-12-31
# Wrote: github_stats_2024.pkl
# -----------------------------
# Extracting data for ros2/console_bridge from 2024-01-01 to 2024-12-31
# Extracting data for ros2/console_bridge from 2023-01-01 to 2023-12-31
# Wrote: github_stats_2024.pkl
# -----------------------------
# Extracting data for ros2/docs.ros2.org from 2024-01-01 to 2024-12-31
# Extracting data for ros2/docs.ros2.org from 2023-01-01 to 2023-12-31
# Wrote: github_stats_2024.pkl
# -----------------------------
# Extracting data for ros2/rviz from 2024-01-01 to 2024-12-31
# Extracting data for ros2/rviz from 2023-01-01 to 2023-12-31
# Wrote: github_stats_2024.pkl
# -----------------------------
# Extracting data for ros2/kdl_parser from 2024-01-01 to 2024-12-31
# Extracting data for ros2/kdl_parser from 2023-01-01 to 2023-12-31
# Wrote: github_stats_2024.pkl
# -----------------------------
# Extracting data for ros2/urdf from 2024-01-01 to 2024-12-31
# Extracting data for ros2/urdf from 2023-01-01 to 2023-12-31
# Wrote: github_stats_2024.pkl
# -----------------------------
# Extracting data for ros2/tinyxml2_vendor from 2024-01-01 to 2024-12-31
# Extracting data for ros2/tinyxml2_vendor from 2023-01-01 to 2023-12-31
# Wrote: github_stats_2024.pkl
# -----------------------------
# Extracting data for ros2/rosbag2 from 2024-01-01 to 2024-12-31
# Extracting data for ros2/rosbag2 from 2023-01-01 to 2023-12-31
# Wrote: github_stats_2024.pkl
# -----------------------------
# Extracting data for ros2/libyaml_vendor from 2024-01-01 to 2024-12-31
# Extracting data for ros2/libyaml_vendor from 2023-01-01 to 2023-12-31
# Wrote: github_stats_2024.pkl
# -----------------------------
# Extracting data for ros2/rosidl_typesupport_connext from 2024-01-01 to 2024-12-31
# Extracting data for ros2/rosidl_typesupport_connext from 2023-01-01 to 2023-12-31
# Wrote: github_stats_2024.pkl
# -----------------------------
# Extracting data for ros2/rosidl_typesupport_opensplice from 2024-01-01 to 2024-12-31
# Extracting data for ros2/rosidl_typesupport_opensplice from 2023-01-01 to 2023-12-31
# Wrote: github_stats_2024.pkl
# -----------------------------
# Extracting data for ros2/rosidl_python from 2024-01-01 to 2024-12-31
# Extracting data for ros2/rosidl_python from 2023-01-01 to 2023-12-31
# Wrote: github_stats_2024.pkl
# -----------------------------
# Extracting data for ros2/rosidl_defaults from 2024-01-01 to 2024-12-31
# Extracting data for ros2/rosidl_defaults from 2023-01-01 to 2023-12-31
# Wrote: github_stats_2024.pkl
# -----------------------------
# Extracting data for ros2/console_bridge_vendor from 2024-01-01 to 2024-12-31
# Extracting data for ros2/console_bridge_vendor from 2023-01-01 to 2023-12-31
# Wrote: github_stats_2024.pkl
# -----------------------------
# Extracting data for ros2/rmw_cyclonedds from 2024-01-01 to 2024-12-31
# Extracting data for ros2/rmw_cyclonedds from 2023-01-01 to 2023-12-31
# Wrote: github_stats_2024.pkl
# -----------------------------
# Extracting data for ros2/message_filters from 2024-01-01 to 2024-12-31
# Extracting data for ros2/message_filters from 2023-01-01 to 2023-12-31
# Wrote: github_stats_2024.pkl
# -----------------------------
# Extracting data for ros2/variants from 2024-01-01 to 2024-12-31
# Extracting data for ros2/variants from 2023-01-01 to 2023-12-31
# Wrote: github_stats_2024.pkl
# -----------------------------
# Extracting data for ros2/rmw_dps from 2024-01-01 to 2024-12-31
# Extracting data for ros2/rmw_dps from 2023-01-01 to 2023-12-31
# Wrote: github_stats_2024.pkl
# -----------------------------
# Extracting data for ros2/rosidl_typesupport_fastrtps from 2024-01-01 to 2024-12-31
# Extracting data for ros2/rosidl_typesupport_fastrtps from 2023-01-01 to 2023-12-31
# Wrote: github_stats_2024.pkl
# -----------------------------
# Extracting data for ros2/ros2_documentation from 2024-01-01 to 2024-12-31
# Request GET /repos/ros2/ros2_documentation/pulls/4676 failed with 403: Forbidden
# Setting next backoff to 838.265165s
# Extracting data for ros2/ros2_documentation from 2023-01-01 to 2023-12-31
# Wrote: github_stats_2024.pkl
# -----------------------------
# Extracting data for ros2/yaml_cpp_vendor from 2024-01-01 to 2024-12-31
# Extracting data for ros2/yaml_cpp_vendor from 2023-01-01 to 2023-12-31
# Wrote: github_stats_2024.pkl
# -----------------------------
# Extracting data for ros2/performance_test from 2024-01-01 to 2024-12-31
# Extracting data for ros2/performance_test from 2023-01-01 to 2023-12-31
# Wrote: github_stats_2024.pkl
# -----------------------------
# Extracting data for ros2/unique_identifier_msgs from 2024-01-01 to 2024-12-31
# Extracting data for ros2/unique_identifier_msgs from 2023-01-01 to 2023-12-31
# Wrote: github_stats_2024.pkl
# -----------------------------
# Extracting data for ros2/rcl_logging from 2024-01-01 to 2024-12-31
# Extracting data for ros2/rcl_logging from 2023-01-01 to 2023-12-31
# Wrote: github_stats_2024.pkl
# -----------------------------
# Extracting data for ros2/tinydir_vendor from 2024-01-01 to 2024-12-31
# Extracting data for ros2/tinydir_vendor from 2023-01-01 to 2023-12-31
# Wrote: github_stats_2024.pkl
# -----------------------------
# Extracting data for ros2/test_interface_files from 2024-01-01 to 2024-12-31
# Extracting data for ros2/test_interface_files from 2023-01-01 to 2023-12-31
# Wrote: github_stats_2024.pkl
# -----------------------------
# Extracting data for ros2/rosbridge_suite from 2024-01-01 to 2024-12-31
# Extracting data for ros2/rosbridge_suite from 2023-01-01 to 2023-12-31
# Wrote: github_stats_2024.pkl
# -----------------------------
# Extracting data for ros2/apex_rostest from 2024-01-01 to 2024-12-31
# Extracting data for ros2/apex_rostest from 2023-01-01 to 2023-12-31
# Wrote: github_stats_2024.pkl
# -----------------------------
# Extracting data for ros2/rcpputils from 2024-01-01 to 2024-12-31
# Extracting data for ros2/rcpputils from 2023-01-01 to 2023-12-31
# Wrote: github_stats_2024.pkl
# -----------------------------
# Extracting data for ros2/launch_ros from 2024-01-01 to 2024-12-31
# Extracting data for ros2/launch_ros from 2023-01-01 to 2023-12-31
# Wrote: github_stats_2024.pkl
# -----------------------------
# Extracting data for ros2/rosbag2_bag_v2 from 2024-01-01 to 2024-12-31
# Extracting data for ros2/rosbag2_bag_v2 from 2023-01-01 to 2023-12-31
# Wrote: github_stats_2024.pkl
# -----------------------------
# Extracting data for ros2/ros_testing from 2024-01-01 to 2024-12-31
# Extracting data for ros2/ros_testing from 2023-01-01 to 2023-12-31
# Wrote: github_stats_2024.pkl
# -----------------------------
# Extracting data for ros2/rmw_gurumdds from 2024-01-01 to 2024-12-31
# Extracting data for ros2/rmw_gurumdds from 2023-01-01 to 2023-12-31
# Wrote: github_stats_2024.pkl
# -----------------------------
# Extracting data for ros2/rosidl_typesupport_gurumdds from 2024-01-01 to 2024-12-31
# Extracting data for ros2/rosidl_typesupport_gurumdds from 2023-01-01 to 2023-12-31
# Wrote: github_stats_2024.pkl
# -----------------------------
# Extracting data for ros2/pybind11_vendor from 2024-01-01 to 2024-12-31
# Extracting data for ros2/pybind11_vendor from 2023-01-01 to 2023-12-31
# Wrote: github_stats_2024.pkl
# -----------------------------
# Extracting data for ros2/eigen3_cmake_module from 2024-01-01 to 2024-12-31
# Extracting data for ros2/eigen3_cmake_module from 2023-01-01 to 2023-12-31
# Wrote: github_stats_2024.pkl
# -----------------------------
# Extracting data for ros2/ifcfg_vendor from 2024-01-01 to 2024-12-31
# Extracting data for ros2/ifcfg_vendor from 2023-01-01 to 2023-12-31
# Wrote: github_stats_2024.pkl
# -----------------------------
# Extracting data for ros2/rmw_dds_common from 2024-01-01 to 2024-12-31
# Extracting data for ros2/rmw_dds_common from 2023-01-01 to 2023-12-31
# Wrote: github_stats_2024.pkl
# -----------------------------
# Extracting data for ros2/darknet_vendor from 2024-01-01 to 2024-12-31
# Extracting data for ros2/darknet_vendor from 2023-01-01 to 2023-12-31
# Wrote: github_stats_2024.pkl
# -----------------------------
# Extracting data for ros2/buildfarm_perf_tests from 2024-01-01 to 2024-12-31
# Extracting data for ros2/buildfarm_perf_tests from 2023-01-01 to 2023-12-31
# Wrote: github_stats_2024.pkl
# -----------------------------
# Extracting data for ros2/rosidl_runtime_py from 2024-01-01 to 2024-12-31
# Extracting data for ros2/rosidl_runtime_py from 2023-01-01 to 2023-12-31
# Wrote: github_stats_2024.pkl
# -----------------------------
# Extracting data for ros2/python_cmake_module from 2024-01-01 to 2024-12-31
# Extracting data for ros2/python_cmake_module from 2023-01-01 to 2023-12-31
# Wrote: github_stats_2024.pkl
# -----------------------------
# Extracting data for ros2/spdlog_vendor from 2024-01-01 to 2024-12-31
# Extracting data for ros2/spdlog_vendor from 2023-01-01 to 2023-12-31
# Wrote: github_stats_2024.pkl
# -----------------------------
# Extracting data for ros2/slide_show from 2024-01-01 to 2024-12-31
# Extracting data for ros2/slide_show from 2023-01-01 to 2023-12-31
# Wrote: github_stats_2024.pkl
# -----------------------------
# Extracting data for ros2/detection_visualizer from 2024-01-01 to 2024-12-31
# Extracting data for ros2/detection_visualizer from 2023-01-01 to 2023-12-31
# Wrote: github_stats_2024.pkl
# -----------------------------
# Extracting data for ros2/openrobotics_darknet_ros from 2024-01-01 to 2024-12-31
# Extracting data for ros2/openrobotics_darknet_ros from 2023-01-01 to 2023-12-31
# Wrote: github_stats_2024.pkl
# -----------------------------
# Extracting data for ros2/rmw_iceoryx from 2024-01-01 to 2024-12-31
# Extracting data for ros2/rmw_iceoryx from 2023-01-01 to 2023-12-31
# Wrote: github_stats_2024.pkl
# -----------------------------
# Extracting data for ros2/ros2_tracing from 2024-01-01 to 2024-12-31
# Extracting data for ros2/ros2_tracing from 2023-01-01 to 2023-12-31
# Wrote: github_stats_2024.pkl
# -----------------------------
# Extracting data for ros2/tsc_working_group_governance_template from 2024-01-01 to 2024-12-31
# Extracting data for ros2/tsc_working_group_governance_template from 2023-01-01 to 2023-12-31
# Wrote: github_stats_2024.pkl
# -----------------------------
# Extracting data for ros2/quality_declarations from 2024-01-01 to 2024-12-31
# Extracting data for ros2/quality_declarations from 2023-01-01 to 2023-12-31
# Wrote: github_stats_2024.pkl
# -----------------------------
# Extracting data for ros2/rpyutils from 2024-01-01 to 2024-12-31
# Extracting data for ros2/rpyutils from 2023-01-01 to 2023-12-31
# Wrote: github_stats_2024.pkl
# -----------------------------
# Extracting data for ros2/ros2_generate_interface_docs from 2024-01-01 to 2024-12-31
# Extracting data for ros2/ros2_generate_interface_docs from 2023-01-01 to 2023-12-31
# Wrote: github_stats_2024.pkl
# -----------------------------
# Extracting data for ros2/middleware_working_group from 2024-01-01 to 2024-12-31
# Extracting data for ros2/middleware_working_group from 2023-01-01 to 2023-12-31
# Wrote: github_stats_2024.pkl
# -----------------------------
# Extracting data for ros2/mimick_vendor from 2024-01-01 to 2024-12-31
# Extracting data for ros2/mimick_vendor from 2023-01-01 to 2023-12-31
# Wrote: github_stats_2024.pkl
# -----------------------------
# Extracting data for ros2/rmw_zenoh from 2024-01-01 to 2024-12-31
# Extracting data for ros2/rmw_zenoh from 2023-01-01 to 2023-12-31
# Wrote: github_stats_2024.pkl
# -----------------------------
# Extracting data for ros2/ros2cli_common_extensions from 2024-01-01 to 2024-12-31
# Extracting data for ros2/ros2cli_common_extensions from 2023-01-01 to 2023-12-31
# Wrote: github_stats_2024.pkl
# -----------------------------
# Extracting data for ros2/performance_test_fixture from 2024-01-01 to 2024-12-31
# Extracting data for ros2/performance_test_fixture from 2023-01-01 to 2023-12-31
# Wrote: github_stats_2024.pkl
# -----------------------------
# Extracting data for ros2/Mimick from 2024-01-01 to 2024-12-31
# Extracting data for ros2/Mimick from 2023-01-01 to 2023-12-31
# Wrote: github_stats_2024.pkl
# -----------------------------
# Extracting data for ros2/unique_identifier from 2024-01-01 to 2024-12-31
# Extracting data for ros2/unique_identifier from 2023-01-01 to 2023-12-31
# Wrote: github_stats_2024.pkl
# -----------------------------
# Extracting data for ros2/rmw_connextdds from 2024-01-01 to 2024-12-31
# Extracting data for ros2/rmw_connextdds from 2023-01-01 to 2023-12-31
# Wrote: github_stats_2024.pkl
# -----------------------------
# Extracting data for ros2/domain_bridge from 2024-01-01 to 2024-12-31
# Extracting data for ros2/domain_bridge from 2023-01-01 to 2023-12-31
# Wrote: github_stats_2024.pkl
# -----------------------------
# Extracting data for ros2/ros_network_viz from 2024-01-01 to 2024-12-31
# Extracting data for ros2/ros_network_viz from 2023-01-01 to 2023-12-31
# Wrote: github_stats_2024.pkl
# -----------------------------
# Extracting data for ros2/orocos_kdl_vendor from 2024-01-01 to 2024-12-31
# Extracting data for ros2/orocos_kdl_vendor from 2023-01-01 to 2023-12-31
# Wrote: github_stats_2024.pkl
# -----------------------------
# Extracting data for ros2/netperf from 2024-01-01 to 2024-12-31
# Extracting data for ros2/netperf from 2023-01-01 to 2023-12-31
# Wrote: github_stats_2024.pkl
# -----------------------------
# Extracting data for ros2/rcl_content_filter_fallback from 2024-01-01 to 2024-12-31
# Extracting data for ros2/rcl_content_filter_fallback from 2023-01-01 to 2023-12-31
# Wrote: github_stats_2024.pkl
# -----------------------------
# Extracting data for ros2/rosidl_core from 2024-01-01 to 2024-12-31
# Extracting data for ros2/rosidl_core from 2023-01-01 to 2023-12-31
# Wrote: github_stats_2024.pkl
# -----------------------------
# Extracting data for ros2/ros2_dds_profiles_examples from 2024-01-01 to 2024-12-31
# Extracting data for ros2/ros2_dds_profiles_examples from 2023-01-01 to 2023-12-31
# Wrote: github_stats_2024.pkl
# -----------------------------
# Extracting data for ros2/rosidl_dynamic_typesupport_fastrtps from 2024-01-01 to 2024-12-31
# Extracting data for ros2/rosidl_dynamic_typesupport_fastrtps from 2023-01-01 to 2023-12-31
# Wrote: github_stats_2024.pkl
# -----------------------------
# Extracting data for ros2/rosidl_dynamic_typesupport from 2024-01-01 to 2024-12-31
# Extracting data for ros2/rosidl_dynamic_typesupport from 2023-01-01 to 2023-12-31
# Wrote: github_stats_2024.pkl
# -----------------------------
# Extracting data for ros2/release-tracking from 2024-01-01 to 2024-12-31
# Extracting data for ros2/release-tracking from 2023-01-01 to 2023-12-31
# Wrote: github_stats_2024.pkl
# -----------------------------
# Extracting data for ros2/.github from 2024-01-01 to 2024-12-31
# Extracting data for ros2/.github from 2023-01-01 to 2023-12-31
# Wrote: github_stats_2024.pkl
# -----------------------------

# %%
out =  None
with open(fname, 'rb') as file:
        out = pickle.load(file)      
print(len(out.keys()))
print(out.keys())
# Out:
# 138
# dict_keys(['design', 'rosidl', 'examples', 'rosidl_dds', 'rmw', 'rmw_connext', 'rclcpp', 'rmw_opensplice', 'ros2_embedded_freertos', 'ros2_embedded_sublime', 'ros2_embedded_riot', 'ros2_embedded_nuttx', 'stlink', 'tinq-core', 'ros_core_documentation', 'freertps', 'rclc', 'rcl', 'ros2', 'launch', 'rmw_implementation', 'rcl_interfaces', 'system_tests', 'rmw_fastrtps', 'common_interfaces', 'ros1_bridge', 'realtime_support', 'demos', 'rmw_freertps', 'ros2.github.io', 'poco_vendor', 'rclpy', 'tlsf', 'turtlebot2_demo', 'ros_astra_camera', 'ci', 'cookbook', 'rosidl_typesupport', 'tutorials', 'sros2', 'ament_cmake_ros', 'rcutils', 'joystick_drivers_from_scratch', 'ros2doc', 'navigation', 'robot_model', 'robot_state_publisher', 'orocos_kinematics_dynamics', 'tinyxml_vendor', 'urdfdom', 'urdfdom_headers', 'geometry2', 'cartographer_ros', 'choco-packages', 'build_farmer', 'vision_opencv', 'pcl_conversions', 'example_interfaces', 'rosdistro', 'ros_buildfarm_config', 'ros_workspace', 'joystick_drivers', 'ceres-solver', 'cartographer', 'depthimage_to_laserscan', 'teleop_twist_joy', 'ros2cli', 'teleop_twist_keyboard', 'console_bridge', 'docs.ros2.org', 'rviz', 'kdl_parser', 'urdf', 'tinyxml2_vendor', 'rosbag2', 'libyaml_vendor', 'rosidl_typesupport_connext', 'rosidl_typesupport_opensplice', 'rosidl_python', 'rosidl_defaults', 'console_bridge_vendor', 'rmw_cyclonedds', 'message_filters', 'variants', 'rmw_dps', 'rosidl_typesupport_fastrtps', 'ros2_documentation', 'yaml_cpp_vendor', 'performance_test', 'unique_identifier_msgs', 'rcl_logging', 'tinydir_vendor', 'test_interface_files', 'rosbridge_suite', 'apex_rostest', 'rcpputils', 'launch_ros', 'rosbag2_bag_v2', 'ros_testing', 'rmw_gurumdds', 'rosidl_typesupport_gurumdds', 'pybind11_vendor', 'eigen3_cmake_module', 'ifcfg_vendor', 'rmw_dds_common', 'darknet_vendor', 'buildfarm_perf_tests', 'rosidl_runtime_py', 'python_cmake_module', 'spdlog_vendor', 'slide_show', 'detection_visualizer', 'openrobotics_darknet_ros', 'rmw_iceoryx', 'ros2_tracing', 'tsc_working_group_governance_template', 'quality_declarations', 'rpyutils', 'ros2_generate_interface_docs', 'middleware_working_group', 'mimick_vendor', 'rmw_zenoh', 'ros2cli_common_extensions', 'performance_test_fixture', 'Mimick', 'unique_identifier', 'rmw_connextdds', 'domain_bridge', 'ros_network_viz', 'orocos_kdl_vendor', 'netperf', 'rcl_content_filter_fallback', 'rosidl_core', 'ros2_dds_profiles_examples', 'rosidl_dynamic_typesupport_fastrtps', 'rosidl_dynamic_typesupport', 'release-tracking', '.github'])

# %%
# Do full org aggregation
this_year = 2024
last_year = 2023 

to_agg = ["users","add","del","files"]

full_results = {}
full_results[this_year] = {}
full_results[last_year] = {}

first = True
for key in full_org_results.keys():
    if first:
        full_results[this_year] = {k: full_org_results[key][this_year][k] for k in to_agg}
        full_results[last_year] = {k: full_org_results[key][last_year][k] for k in to_agg}
        full_results[this_year]["prs"] = len(full_org_results[key][this_year]["prs"])
        full_results[last_year]["prs"] = len(full_org_results[key][last_year]["prs"])
        first = False
    else:        
        for a in to_agg:
            full_results[this_year][a] += full_org_results[key][this_year][a]
            full_results[last_year][a] += full_org_results[key][last_year][a]
            full_results[this_year]["prs"] += len(full_org_results[key][this_year]["prs"])
            full_results[last_year]["prs"] += len(full_org_results[key][last_year]["prs"])

full_results[last_year]["contributors"] = set(full_results[last_year]["users"])
full_results[last_year]["users"] = len(set(full_results[last_year]["users"]))

full_results[this_year]["contributors"] = set(full_results[this_year]["users"])
full_results[this_year]["users"] = len(set(full_results[this_year]["users"]))


print("Results for {0} ==> {1}".format(last_year,this_year))
print("-------------------------")
for k in full_results[this_year].keys():
    if k == "contributors":
        continue
    change = -100*(full_results[last_year][k]-full_results[this_year][k])/full_results[last_year][k]
    print("{0:6s}| {1} : {2:<6} | {3} : {4:<6} | {5:4.2f}%".format(k,last_year,full_results[last_year][k],this_year,full_results[this_year][k],change))
print(full_results[this_year]["contributors"])
# Out:
# Results for 2023 ==> 2024
# -------------------------
# users | 2023 : 250    | 2024 : 258    | 3.20%
# add   | 2023 : 293513 | 2024 : 289639 | -1.32%
# del   | 2023 : 95340  | 2024 : 147704 | 54.92%
# files | 2023 : 10039  | 2024 : 11922  | 18.76%
# prs   | 2023 : 9071   | 2024 : 10897  | 20.13%
# {'Hubert Liberacki', 'Adam Aposhian', 'Alireza Moayyedi', 'Cole Tucker', None, 'Lucas Wendland', 'Marco A. Gutierrez', 'Henry Fuller', 'Christian Ruf', 'Gabriele Baldoni', 'Nour Saeed', 'Miguel Company', 'ShiChangshan', 'Nathan Wiebe Neufeldt', 'Marc Bestmann', 'Davide Faconti', 'Joseph Schornak', 'Stefan Fabian', 'Michael Orlov', 'Shivang Vijay', 'Mario Domínguez López', 'Kotaro Yoshimoto', 'Wei HU', 'Christian Bitter', 'Matthijs van der Burgh', 'Eric Su', 'Tomoya Fujita', 'Nicola Loi', 'Wiktoria Siekierska', 'Jannik Jose', 'Trushant Adeshara', 'Liangqian', 'yadunund', 'Audrow Nash', 'Christoph Fröhlich', 'Michael Carlstrom', 'Dominik', 'Vincent Conus', 'Roberto Masocco', 'Mahmoud Mazouz', 'Yannic Bachmann', 'Deleted user', 'Simon Hoinkis', 'Cihat Kurtuluş Altıparmak', 'Kaan Karaalioglu', 'Alejandro R Mosteo', 'Cristóbal Arroyo', 'Jakub Delicat', 'Chen Lihui', 'Daniel Angelov', 'William Woodall', 'Patrick Hammer', 'xueying', 'Daisuke Nishimatsu', 'Hans-Martin Duringhof', 'Mike Purvis', 'Mikael Arguedas', 'Henry Moore', 'Matthias Holoch', 'Jorge J. Perez', 'Lukas Schäper', 'Sascha Arnold', 'Błażej Sowa', 'YR', 'Arne Nordmann', 'Ruffin', 'Addisu Z. Taddese', 'Masayoshi Dohi', 'Alejandro Hernández Cordero', 'Kosuke Takeuchi', 'Mohammed Irfan', 'Steven Palma', 'Barry Xu', 'Adam Huang', 'Logger', 'Tom Moore', 'Michał Pełka', 'Alberto Soragna', 'Jonathan', 'takasehideki', 'Tim Clephas', 'Michael Fishman', 'William Kaiser', 'Aarav Gupta', 'Haidar Obeid', 'Michael Jeronimo', 'Yasushi SHOJI', 'Roman', 'Peter Borkuti', 'Vladimir Fokow', 'Vasily', 'Christoph Hellmann Santos', 'WATANABE Aoi', 'Ramon Wijnands', 'Martin Peris', 'Rhys Mainwaring', 'Eugene Sukhodolin', 'Harry Sarson', 'Thomas Ung', 'Mattis Kieffer', 'Arjo Chakravarty', 'Oren Bell', 'Azmyin Md. Kamal', 'Aditya Agarwal', 'Samim Reza', 'Brian', 'Anton Matosov', 'Ivan Santiago Paunovic', 'Jasmeet Singh', 'CHOI WOEN-SUG', 'Tom Noble', 'Bernd Pfrommer', 'Alexis Paques', 'Aleena', 'Felix Penzlin', 'Ivan Perez, PhD', 'Christopher Wecht', 'Bo Chen', 'Jeffery Hsu', 'Florian Vahl', 'Fangjun Kuang', 'Romain DESILLE', 'brewmaster', 'Michael Ferguson', 'Michael Ripperger', 'Lewe Christiansen', 'Matthew Elwin', 'Stu Donnan', 'Matt Condino', 'Scott K Logan', 'Christophe Bedard', 'Christian Rauch', 'Ethan Zapalac', 'Silvio Traversaro', 'Hyeonwoo Kim', 'Janosch Machowinski', 'harunkurtdev', 'Krishna Shah', 'Andreas Bihlmaier', 'Julien Enoch', 'James Prestwood', 'Peng Wang', 'Shane Loretz', 'John-Henry Lim', 'Alexey Merzlyakov', 'Jesper Smith', 'Gaurav Kumar', 'Abhishek Kashyap', 'Jake Ketchum', 'Janne Karttunen', 'Bernd Müller', 'Kenta Yonekura', 'Lennart Nachtigall', 'Clara Berendsen', 'The Kyan', 'Tim', 'Ronaldson Bellande', 'Felipe Gomes de Melo', 'Russ', 'Christian Flewelling', 'Halvor Platou', 'Franco Cipollone', 'Nate Koenig', 'Dr. Denis', 'Austin Moore', 'Eric.Zhao', 'ChenYing Kuo (CY)', 'iRobot ROS', 'Yuxuan Zhang', 'Alexis Tsogias', 'LihanChen2004', 'Bonolo Mathibela', 'Ruddick Lawrence', 'Taxo Rubio RTI', 'João C. Monteiro', 'VictorLee', 'Kyle Fazzari', 'Sharmin Ramli', 'Sai Kishor Kothakota', 'Pradyum Aadith', 'Clément Chupin', 'Jonas Otto', 'James Mount', 'Eric Cousineau', 'Daisuke Kato', 'Zygfryd Wieszok', 'Katherine Scott', 'Tony Najjar', 'Erick G. Islas-Osuna', 'Shingo Kitagawa', 'Iván López Broceño', 'Bahram Banisadr', 'Dharini Dutia', 'Vincent', 'David Dorf', 'Alex Day', 'Emerson Knapp', 'Mattia Massarenti', 'Alexis Pojomovsky', 'Brett Downing', 'Laurenz', 'Romain Lebbadi-Breteau', 'Yuyuan Yuan', 'BrnBlrg', 'Vignesh Vembar', 'Felix Exner (fexner)', 'RFRIEDM-Trimble', 'Steven! Ragnarök', 'Tamaki Nishino', 'Ignacio Vizzo', 'Eduardo Ponz Segrelles', 'Tobias Fischer', 'Nidhi Chidambar', 'SangtaekLee', 'Tavienne Millner', 'Patrick Roncagliolo', 'Albert Li', 'Jan Staschulat', 'Felix', 'methylDragon', 'so-T', 'Steve Peters', 'Mateusz Lichota', 'Roman Shtylman', 'Kimberly N. McGuire', 'David V. Lu!!', 'G.A. vd. Hoorn', 'Dave Collins', 'Michael Carroll', 'Yaswanth', 'Camilo Camacho',  ...

# %%
target = "add"
agg_result = []
for key in full_org_results.keys():
    a = full_org_results[key][this_year][target]
    b = full_org_results[key][last_year][target]
    delta = 0.00
    if b > 0:
        delta = (-100.0*(b-a)/b)
    temp = {}
    temp["name"] = key
    temp[this_year] = a
    temp[last_year] = b
    temp["change"] = delta
    agg_result.append(temp)
    
newlist = sorted(agg_result, key=lambda d: d[this_year])
newlist.reverse()
print("Results for '{0}' across ROS 2 org".format(target))
print("-------------------------------------------------------------------")
for i in newlist:  
    print("{0:24s}| 2023: {1:<5} | 2024: {2:<5} | delta: {3:4.2f}%".format(i["name"][:24],
                                                                           i[last_year],
                                                                           i[this_year],
                                                                           i["change"]))
    
df = pd.DataFrame(data=newlist)
df.to_csv("ROS2NewLines.csv")
# Out:
# Results for 'add' across ROS 2 org
# -------------------------------------------------------------------
# ros2_documentation      | 2023: 73187 | 2024: 58785 | delta: -19.68%
# rosbag2                 | 2023: 28025 | 2024: 35738 | delta: 27.52%
# rmw_zenoh               | 2023: 11206 | 2024: 29361 | delta: 162.01%
# geometry2               | 2023: 2651  | 2024: 27018 | delta: 919.16%
# rviz                    | 2023: 21139 | 2024: 24258 | delta: 14.75%
# rclcpp                  | 2023: 35802 | 2024: 22643 | delta: -36.75%
# message_filters         | 2023: 1264  | 2024: 14311 | delta: 1032.20%
# rcl                     | 2023: 13237 | 2024: 8246  | delta: -37.70%
# rcpputils               | 2023: 135   | 2024: 7790  | delta: 5670.37%
# rclpy                   | 2023: 6635  | 2024: 7734  | delta: 16.56%
# rmw_gurumdds            | 2023: 104   | 2024: 7104  | delta: 6730.77%
# ros1_bridge             | 2023: 1958  | 2024: 6943  | delta: 254.60%
# ros2_tracing            | 2023: 3665  | 2024: 5830  | delta: 59.07%
# ros_buildfarm_config    | 2023: 3603  | 2024: 4079  | delta: 13.21%
# common_interfaces       | 2023: 169   | 2024: 2831  | delta: 1575.15%
# ros2cli                 | 2023: 1976  | 2024: 2733  | delta: 38.31%
# rclc                    | 2023: 4394  | 2024: 2480  | delta: -43.56%
# rosidl                  | 2023: 17722 | 2024: 2411  | delta: -86.40%
# sros2                   | 2023: 9     | 2024: 1648  | delta: 18211.11%
# demos                   | 2023: 7355  | 2024: 1414  | delta: -80.77%
# rmw_connextdds          | 2023: 4386  | 2024: 1398  | delta: -68.13%
# rosidl_typesupport_fastr| 2023: 577   | 2024: 1390  | delta: 140.90%
# rcutils                 | 2023: 2229  | 2024: 1320  | delta: -40.78%
# examples                | 2023: 9985  | 2024: 1246  | delta: -87.52%
# rmw_fastrtps            | 2023: 3832  | 2024: 1078  | delta: -71.87%
# ci                      | 2023: 535   | 2024: 957   | delta: 78.88%
# urdf                    | 2023: 15    | 2024: 895   | delta: 5866.67%
# launch                  | 2023: 1286  | 2024: 859   | delta: -33.20%
# system_tests            | 2023: 779   | 2024: 830   | delta: 6.55%
# rmw_implementation      | 2023: 731   | 2024: 762   | delta: 4.24%
# launch_ros              | 2023: 432   | 2024: 731   | delta: 69.21%
# ros2                    | 2023: 388   | 2024: 623   | delta: 60.57%
# teleop_twist_joy        | 2023: 52    | 2024: 519   | delta: 898.08%
# rmw_cyclonedds          | 2023: 767   | 2024: 406   | delta: -47.07%
# rmw_dds_common          | 2023: 785   | 2024: 391   | delta: -50.19%
# rcl_logging             | 2023: 81    | 2024: 275   | delta: 239.51%
# cartographer            | 2023: 0     | 2024: 273   | delta: 0.00%
# unique_identifier_msgs  | 2023: 3     | 2024: 272   | delta: 8966.67%
# pybind11_vendor         | 2023: 138   | 2024: 221   | delta: 60.14%
# rmw                     | 2023: 1345  | 2024: 211   | delta: -84.31%
# orocos_kdl_vendor       | 2023: 24    | 2024: 178   | delta: 641.67%
# cartographer_ros        | 2023: 0     | 2024: 169   | delta: 0.00%
# performance_test        | 2023: 0     | 2024: 166   | delta: 0.00%
# rosidl_python           | 2023: 335   | 2024: 151   | delta: -54.93%
# rosidl_typesupport      | 2023: 833   | 2024: 131   | delta: -84.27%
# python_cmake_module     | 2023: 0     | 2024: 121   | delta: 0.00%
# rmw_iceoryx             | 2023: 2615  | 2024: 114   | delta: -95.64%
# Mimick                  | 2023: 20    | 2024: 109   | delta: 445.00%
# libyaml_vendor          | 2023: 49    | 2024: 60    | delta: 22.45%
# design                  | 2023: 155   | 2024: 58    | delta: -62.58%
# .github                 | 2023: 0     | 2024: 56    | delta: 0.00%
# yaml_cpp_vendor         | 2023: 43    | 2024: 50    | delta: 16.28%
# rpyutils                | 2023: 2     | 2024: 48    | delta: 2300.00%
# ros_testing             | 2023: 0     | 2024: 29    | delta: 0.00%
# realtime_support        | 2023: 7     | 2024: 27    | delta: 285.71%
# ament_cmake_ros         | 2023: 0     | 2024: 24    | delta: 0.00%
# rosidl_core             | 2023: 0     | 2024: 19    | delta: 0.00%
# buildfarm_perf_tests    | 2023: 0     | 2024: 15    | delta: 0.00%
# console_bridge_vendor   | 2023: 31    | 2024: 15    | delta: -51.61%
# rcl_interfaces          | 2023: 11664 | 2024: 14    | delta: -99.88%
# rosidl_runtime_py       | 2023: 25    | 2024: 13    | delta: -48.00%
# performance_test_fixture| 2023: 11    | 2024: 12    | delta: 9.09%
# spdlog_vendor           | 2023: 19    | 2024: 11    | delta: -42.11%
# variants                | 2023: 0     | 2024: 11    | delta: 0.00%
# mimick_vendor           | 2023: 15    | 2024: 8     | delta: -46.67%
# ros_network_viz         | 2023: 0     | 2024: 7     | delta: 0.00%
# rosidl_defaults         | 2023: 2     | 2024: 5     | delta: 150.00%
# rosidl_dds              | 2023: 15    | 2024: 2     | delta: -86.67%
# openrobotics_darknet_ros| 2023: 291   | 2024: 1     | delta: -99.66%
# tlsf                    | 2023: 0     | 2024: 1     | delta: 0.00%
# release-tracking        | 2023: 0     | 2024: 0     | delta: 0.00%
# rosidl_dynamic_typesuppo| 2023: 8102  | 2024: 0     | delta: -100.00%
# rosidl_dynamic_typesuppo| 2023: 5992  | 2024: 0     | delta: -100.00%
# ros2_dds_profiles_exampl| 2023: 0     | 2024: 0     | delta: 0.00%
# rcl_content_filter_fallb| 2023: 0     | 2024: 0     | delta: 0.00%
# netperf                 | 2023: 0     | 2024: 0     | delta: 0.00%
# domain_bridge           | 2023: 128   | 2024: 0     | delta: -100.00%
# unique_identifier       | 2023: 0     | 2024: 0     | delta: 0.00%
# ros2cli_common_extension| 2023: 0     | 2024: 0     | delta: 0.00%
# middleware_working_group| 2023: 0     | 2024: 0     | delta: 0.00%
# ros2_generate_interface_| 2023: 0     | 2024: 0     | delta: 0.00%
# quality_declarations    | 2023: 0     | 2024: 0     | delta: 0.00%
# tsc_working_group_govern| 2023: 0     | 2024: 0     | delta: 0.00%
# detection_visualizer    | 2023: 8     | 2024: 0     | delta: -100.00%
# slide_show              | 2023: 0     | 2024: 0     | delta: 0.00%
# darknet_vendor          | 2023: 0     | 2024: 0     | delta: 0.00%
# ifcfg_vendor            | 2023: 0     | 2024: 0     | delta: 0.00%
# eigen3_cmake_module     | 2023: 0     | 2024: 0     | delta: 0.00%
# rosidl_typesupport_gurum| 2023: 0     | 2024: 0     | delta: 0.00%
# rosbag2_bag_v2          | 2023: 0     | 2024: 0     | delta: 0.00%
# apex_rostest            | 2023: 0     | 2024: 0     | delta: 0.00%
# rosbridge_suite         | 2023: 0     | 2024: 0     | delta: 0.00%
# test_interface_files    | 2023: 37    | 2024: 0     | delta: -100.00%
# tinydir_vendor          | 2023: 0     | 2024: 0     | delta: 0.00%
# rmw_dps                 | 2023: 0     | 2024: 0     | delta: 0.00%
# rosidl_typesupport_opens| 2023: 0     | 2024: 0     | delta: 0.00%
# rosidl_typesupport_conne| 2023: 0     | 2024: 0     | delta: 0.00%
# tinyxml2_vendor         | 2023: 9     | 2024: 0     | delta: -100.00%
# kdl_parser              | 2023: 0     | 2024: 0     | delta: 0.00%
# docs.ros2.org           | 2023: 0     | 2024: 0     | delta: 0.00%
# console_bridge          | 2023: 0     | 2024: 0     | delta: 0.00%
# teleop_twist_keyboard   | 2023: 54    | 2024: 0     | delta: -100.00%
# depthimage_to_laserscan | 2023: 0     | 2024: 0     | delta: 0.00%
# ceres-solver            | 2023: 0     | 2024: 0     | delta: 0.00%
# joystick_drivers        | 2023: 0     | 2024: 0     | delta: 0.00%
# ros_workspace           | 2023: 2     | 2024: 0     | delta: -100.00%
# rosdistro               | 2023: 0     | 2024: 0     | delta: 0.00%
# example_interfaces      | 2023: 3     | 2024: 0     | delta: -100.00%
# pcl_conversions         | 2023: 0     | 2024: 0     | delta: 0.00%
# vision_opencv           | 2023: 0     | 2024: 0     | delta: 0.00%
# build_farmer            | 2023: 0     | 2024: 0     | delta: 0.00%
# choco-packages          | 2023: 0     | 2024: 0     | delta: 0.00%
# urdfdom_headers         | 2023: 0     | 2024: 0     | delta: 0.00%
# urdfdom                 | 2023: 0     | 2024: 0     | delta: 0.00%
# tinyxml_vendor          | 2023: 0     | 2024: 0     | delta: 0.00%
# orocos_kinematics_dynami| 2023: 0     | 2024: 0     | delta: 0.00%
# robot_state_publisher   | 2023: 0     | 2024: 0     | delta: 0.00%
# robot_model             | 2023: 0     | 2024: 0     | delta: 0.00%
# navigation              | 2023: 0     | 2024: 0     | delta: 0.00%
# ros2doc                 | 2023: 0     | 2024: 0     | delta: 0.00%
# joystick_drivers_from_sc| 2023: 0     | 2024: 0     | delta: 0.00%
# tutorials               | 2023: 0     | 2024: 0     | delta: 0.00%
# cookbook                | 2023: 0     | 2024: 0     | delta: 0.00%
# ros_astra_camera        | 2023: 0     | 2024: 0     | delta: 0.00%
# turtlebot2_demo         | 2023: 0     | 2024: 0     | delta: 0.00%
# poco_vendor             | 2023: 0     | 2024: 0     | delta: 0.00%
# ros2.github.io          | 2023: 0     | 2024: 0     | delta: 0.00%
# rmw_freertps            | 2023: 0     | 2024: 0     | delta: 0.00%
# freertps                | 2023: 0     | 2024: 0     | delta: 0.00%
# ros_core_documentation  | 2023: 0     | 2024: 0     | delta: 0.00%
# tinq-core               | 2023: 0     | 2024: 0     | delta: 0.00%
# stlink                  | 2023: 0     | 2024: 0     | delta: 0.00%
# ros2_embedded_nuttx     | 2023: 0     | 2024: 0     | delta: 0.00%
# ros2_embedded_riot      | 2023: 0     | 2024: 0     | delta: 0.00%
# ros2_embedded_sublime   | 2023: 0     | 2024: 0     | delta: 0.00%
# ros2_embedded_freertos  | 2023: 0     | 2024: 0     | delta: 0.00%
# rmw_opensplice          | 2023: 0     | 2024: 0     | delta: 0.00%
# rmw_connext             | 2023: 440   | 2024: 0     | delta: -100.00%

# %%
target = "prs"

agg_result = []
for key in full_org_results.keys():
    a = len(full_org_results[key][2024][target])
    b = len(full_org_results[key][2023][target])
    delta = 0.00
    if b > 0:
        delta = (-100.0*(b-a)/b)
    temp = {}
    temp["name"] = key
    temp[this_year] = a
    temp[last_year] = b
    temp["change"] = delta
    agg_result.append(temp)
    
newlist = sorted(agg_result, key=lambda d: d[this_year])
newlist.reverse()
print("PR count by year")
print("Results for '{0}' across ROS 2 org".format(target))
print("-------------------------------------------------------------------")
for i in newlist:  
    print("{0:24s}| 2023: {1:<5} | 2024: {2:<5} | delta: {3:4.2f}%".format(i["name"][:24],
                                                                           i[last_year],
                                                                           i[this_year],
                                                                           i["change"]))
df = pd.DataFrame(data=newlist)
df.to_csv("ROS2PullRequests.csv")
# Out:
# PR count by year
# Results for 'prs' across ROS 2 org
# -------------------------------------------------------------------
# ros2_documentation      | 2023: 723   | 2024: 748   | delta: 3.46%
# rosbag2                 | 2023: 202   | 2024: 278   | delta: 37.62%
# rclcpp                  | 2023: 191   | 2024: 213   | delta: 11.52%
# rmw_zenoh               | 2023: 18    | 2024: 177   | delta: 883.33%
# rviz                    | 2023: 123   | 2024: 138   | delta: 12.20%
# rclpy                   | 2023: 96    | 2024: 128   | delta: 33.33%
# geometry2               | 2023: 44    | 2024: 75    | delta: 70.45%
# ci                      | 2023: 42    | 2024: 61    | delta: 45.24%
# rcl                     | 2023: 82    | 2024: 61    | delta: -25.61%
# ros2_tracing            | 2023: 41    | 2024: 54    | delta: 31.71%
# ros2cli                 | 2023: 58    | 2024: 53    | delta: -8.62%
# rosidl                  | 2023: 39    | 2024: 48    | delta: 23.08%
# demos                   | 2023: 55    | 2024: 40    | delta: -27.27%
# message_filters         | 2023: 12    | 2024: 38    | delta: 216.67%
# rcutils                 | 2023: 25    | 2024: 34    | delta: 36.00%
# rmw_fastrtps            | 2023: 52    | 2024: 34    | delta: -34.62%
# launch                  | 2023: 20    | 2024: 33    | delta: 65.00%
# ros2                    | 2023: 30    | 2024: 32    | delta: 6.67%
# launch_ros              | 2023: 22    | 2024: 28    | delta: 27.27%
# sros2                   | 2023: 3     | 2024: 26    | delta: 766.67%
# common_interfaces       | 2023: 9     | 2024: 26    | delta: 188.89%
# ros_buildfarm_config    | 2023: 32    | 2024: 24    | delta: -25.00%
# rmw_connextdds          | 2023: 29    | 2024: 23    | delta: -20.69%
# rmw_implementation      | 2023: 7     | 2024: 22    | delta: 214.29%
# rcpputils               | 2023: 10    | 2024: 21    | delta: 110.00%
# rmw_cyclonedds          | 2023: 19    | 2024: 21    | delta: 10.53%
# system_tests            | 2023: 22    | 2024: 21    | delta: -4.55%
# examples                | 2023: 7     | 2024: 20    | delta: 185.71%
# rmw                     | 2023: 23    | 2024: 17    | delta: -26.09%
# rcl_logging             | 2023: 4     | 2024: 15    | delta: 275.00%
# rosidl_python           | 2023: 6     | 2024: 14    | delta: 133.33%
# performance_test        | 2023: 1     | 2024: 13    | delta: 1200.00%
# teleop_twist_joy        | 2023: 4     | 2024: 13    | delta: 225.00%
# rosidl_typesupport      | 2023: 16    | 2024: 12    | delta: -25.00%
# rosidl_typesupport_fastr| 2023: 18    | 2024: 10    | delta: -44.44%
# rclc                    | 2023: 67    | 2024: 10    | delta: -85.07%
# orocos_kdl_vendor       | 2023: 3     | 2024: 9     | delta: 200.00%
# mimick_vendor           | 2023: 4     | 2024: 8     | delta: 100.00%
# urdf                    | 2023: 1     | 2024: 8     | delta: 700.00%
# yaml_cpp_vendor         | 2023: 4     | 2024: 6     | delta: 50.00%
# libyaml_vendor          | 2023: 6     | 2024: 6     | delta: -0.00%
# Mimick                  | 2023: 4     | 2024: 5     | delta: 25.00%
# performance_test_fixture| 2023: 2     | 2024: 5     | delta: 150.00%
# spdlog_vendor           | 2023: 2     | 2024: 5     | delta: 150.00%
# rosidl_runtime_py       | 2023: 2     | 2024: 5     | delta: 150.00%
# unique_identifier_msgs  | 2023: 1     | 2024: 5     | delta: 400.00%
# rcl_interfaces          | 2023: 11    | 2024: 5     | delta: -54.55%
# design                  | 2023: 3     | 2024: 5     | delta: 66.67%
# rpyutils                | 2023: 1     | 2024: 4     | delta: 300.00%
# python_cmake_module     | 2023: 0     | 2024: 4     | delta: 0.00%
# pybind11_vendor         | 2023: 4     | 2024: 4     | delta: -0.00%
# variants                | 2023: 0     | 2024: 4     | delta: 0.00%
# realtime_support        | 2023: 2     | 2024: 4     | delta: 100.00%
# rosidl_core             | 2023: 0     | 2024: 3     | delta: 0.00%
# rmw_iceoryx             | 2023: 14    | 2024: 3     | delta: -78.57%
# buildfarm_perf_tests    | 2023: 0     | 2024: 3     | delta: 0.00%
# rmw_dds_common          | 2023: 8     | 2024: 3     | delta: -62.50%
# rmw_gurumdds            | 2023: 3     | 2024: 3     | delta: -0.00%
# ros_testing             | 2023: 0     | 2024: 3     | delta: 0.00%
# test_interface_files    | 2023: 2     | 2024: 3     | delta: 50.00%
# console_bridge_vendor   | 2023: 3     | 2024: 3     | delta: -0.00%
# rosidl_defaults         | 2023: 1     | 2024: 3     | delta: 200.00%
# cartographer_ros        | 2023: 0     | 2024: 3     | delta: 0.00%
# ament_cmake_ros         | 2023: 0     | 2024: 3     | delta: 0.00%
# tlsf                    | 2023: 0     | 2024: 3     | delta: 0.00%
# ros1_bridge             | 2023: 8     | 2024: 3     | delta: -62.50%
# ros2cli_common_extension| 2023: 0     | 2024: 2     | delta: 0.00%
# eigen3_cmake_module     | 2023: 0     | 2024: 2     | delta: 0.00%
# tinyxml2_vendor         | 2023: 3     | 2024: 2     | delta: -33.33%
# example_interfaces      | 2023: 1     | 2024: 2     | delta: 100.00%
# rosidl_dds              | 2023: 1     | 2024: 2     | delta: 100.00%
# .github                 | 2023: 0     | 2024: 1     | delta: 0.00%
# rosidl_dynamic_typesuppo| 2023: 9     | 2024: 1     | delta: -88.89%
# rosidl_dynamic_typesuppo| 2023: 4     | 2024: 1     | delta: -75.00%
# ros_network_viz         | 2023: 0     | 2024: 1     | delta: 0.00%
# openrobotics_darknet_ros| 2023: 1     | 2024: 1     | delta: -0.00%
# cartographer            | 2023: 0     | 2024: 1     | delta: 0.00%
# release-tracking        | 2023: 0     | 2024: 0     | delta: 0.00%
# ros2_dds_profiles_exampl| 2023: 0     | 2024: 0     | delta: 0.00%
# rcl_content_filter_fallb| 2023: 0     | 2024: 0     | delta: 0.00%
# netperf                 | 2023: 0     | 2024: 0     | delta: 0.00%
# domain_bridge           | 2023: 1     | 2024: 0     | delta: -100.00%
# unique_identifier       | 2023: 0     | 2024: 0     | delta: 0.00%
# middleware_working_group| 2023: 0     | 2024: 0     | delta: 0.00%
# ros2_generate_interface_| 2023: 0     | 2024: 0     | delta: 0.00%
# quality_declarations    | 2023: 0     | 2024: 0     | delta: 0.00%
# tsc_working_group_govern| 2023: 0     | 2024: 0     | delta: 0.00%
# detection_visualizer    | 2023: 1     | 2024: 0     | delta: -100.00%
# slide_show              | 2023: 0     | 2024: 0     | delta: 0.00%
# darknet_vendor          | 2023: 0     | 2024: 0     | delta: 0.00%
# ifcfg_vendor            | 2023: 0     | 2024: 0     | delta: 0.00%
# rosidl_typesupport_gurum| 2023: 0     | 2024: 0     | delta: 0.00%
# rosbag2_bag_v2          | 2023: 0     | 2024: 0     | delta: 0.00%
# apex_rostest            | 2023: 0     | 2024: 0     | delta: 0.00%
# rosbridge_suite         | 2023: 0     | 2024: 0     | delta: 0.00%
# tinydir_vendor          | 2023: 0     | 2024: 0     | delta: 0.00%
# rmw_dps                 | 2023: 0     | 2024: 0     | delta: 0.00%
# rosidl_typesupport_opens| 2023: 0     | 2024: 0     | delta: 0.00%
# rosidl_typesupport_conne| 2023: 0     | 2024: 0     | delta: 0.00%
# kdl_parser              | 2023: 0     | 2024: 0     | delta: 0.00%
# docs.ros2.org           | 2023: 0     | 2024: 0     | delta: 0.00%
# console_bridge          | 2023: 0     | 2024: 0     | delta: 0.00%
# teleop_twist_keyboard   | 2023: 5     | 2024: 0     | delta: -100.00%
# depthimage_to_laserscan | 2023: 0     | 2024: 0     | delta: 0.00%
# ceres-solver            | 2023: 0     | 2024: 0     | delta: 0.00%
# joystick_drivers        | 2023: 0     | 2024: 0     | delta: 0.00%
# ros_workspace           | 2023: 1     | 2024: 0     | delta: -100.00%
# rosdistro               | 2023: 0     | 2024: 0     | delta: 0.00%
# pcl_conversions         | 2023: 0     | 2024: 0     | delta: 0.00%
# vision_opencv           | 2023: 0     | 2024: 0     | delta: 0.00%
# build_farmer            | 2023: 0     | 2024: 0     | delta: 0.00%
# choco-packages          | 2023: 0     | 2024: 0     | delta: 0.00%
# urdfdom_headers         | 2023: 0     | 2024: 0     | delta: 0.00%
# urdfdom                 | 2023: 0     | 2024: 0     | delta: 0.00%
# tinyxml_vendor          | 2023: 0     | 2024: 0     | delta: 0.00%
# orocos_kinematics_dynami| 2023: 0     | 2024: 0     | delta: 0.00%
# robot_state_publisher   | 2023: 0     | 2024: 0     | delta: 0.00%
# robot_model             | 2023: 0     | 2024: 0     | delta: 0.00%
# navigation              | 2023: 0     | 2024: 0     | delta: 0.00%
# ros2doc                 | 2023: 0     | 2024: 0     | delta: 0.00%
# joystick_drivers_from_sc| 2023: 0     | 2024: 0     | delta: 0.00%
# tutorials               | 2023: 0     | 2024: 0     | delta: 0.00%
# cookbook                | 2023: 0     | 2024: 0     | delta: 0.00%
# ros_astra_camera        | 2023: 0     | 2024: 0     | delta: 0.00%
# turtlebot2_demo         | 2023: 0     | 2024: 0     | delta: 0.00%
# poco_vendor             | 2023: 0     | 2024: 0     | delta: 0.00%
# ros2.github.io          | 2023: 0     | 2024: 0     | delta: 0.00%
# rmw_freertps            | 2023: 0     | 2024: 0     | delta: 0.00%
# freertps                | 2023: 0     | 2024: 0     | delta: 0.00%
# ros_core_documentation  | 2023: 0     | 2024: 0     | delta: 0.00%
# tinq-core               | 2023: 0     | 2024: 0     | delta: 0.00%
# stlink                  | 2023: 0     | 2024: 0     | delta: 0.00%
# ros2_embedded_nuttx     | 2023: 0     | 2024: 0     | delta: 0.00%
# ros2_embedded_riot      | 2023: 0     | 2024: 0     | delta: 0.00%
# ros2_embedded_sublime   | 2023: 0     | 2024: 0     | delta: 0.00%
# ros2_embedded_freertos  | 2023: 0     | 2024: 0     | delta: 0.00%
# rmw_opensplice          | 2023: 0     | 2024: 0     | delta: 0.00%
# rmw_connext             | 2023: 2     | 2024: 0     | delta: -100.00%

# %%
print(full_org_results["rmw"][2024]["users"])
# Out:
# ['Alejandro Hernández Cordero', None, None, 'G.A. vd. Hoorn', 'Felix F Xu', 'Felix F Xu', 'Alejandro Hernández Cordero', 'Christophe Bedard', 'Christophe Bedard', 'Tomoya Fujita', 'Tomoya Fujita', 'Tomoya Fujita', 'Chris Lalancette', None, 'Christophe Bedard', 'Chris Lalancette', 'Chris Lalancette']

# %%
temp = full_org_results["rclcpp"][2024]["prs"][0]

# %%
t2 = temp.user.get_organization_membership("ros2")

# %%
t2.organization
# Out:
# Organization(login="ros2")

# %%
repo = gh.get_repo("ros2/ros2_documentation")

# %%
issues = repo.get_issues()

# %%
for iss in issues[0:10]:
    print(iss)
# Out:
# Issue(title="Requesting ROS 2 words for codespell ROS 2 dictionary support.", number=5004)
# Issue(title="automatic spelling check by sphinx-spelling ext.", number=4998)
# Issue(title="apply one-sentence-per-line rule for rst files via github workflow.", number=4996)
# Issue(title="Minimal service client implementation without using wait_until_future_complete", number=4993)
# Issue(title="Cleanup the Windows instructions for using conda/pixi.", number=4989)
# Issue(title="Add a warning to action doc that it cannot be created under ament_python", number=4986)
# Issue(title="Link to the API in the examples", number=4985)
# Issue(title="Strategies for YAML Message Generation Using ROS CLI", number=4984)
# Issue(title="Added zenoh security documention", number=4977)
# Issue(title="Update Visualizing-ROS-2-Data-With-Foxglove-Studio.rst", number=4954)

# %%
foo = issues[0]

# %%
foo.creat
# Out:
# datetime.datetime(2025, 2, 8, 6, 31, 35, tzinfo=tzutc())

# %%
repo.get_issues?

# %%
this_year_start = date(2024, 1, 1)
this_year_end = date(2024, 12, 31)
start = datetime(2024, 1, 1, 1, 0, 0,0)
issues = repo.get_issues(state="all",since=start)

# %%
foo = issues[0]

# %%
print(foo.pull_request)
for iss in issues:
    if iss.state == "open":
        print("OPEN")
    elif iss.state == "closed": 
        print("Closed")
    #    if this_year_start < iss.closed_at.date() < this_year_end:
    print(iss.user.login)
    print(iss.url)
    print(iss)
    print("---")
# Out:
# <github.IssuePullRequest.IssuePullRequest object at 0x7fe223d50850>
# OPEN
# fujitatomoya
# https://api.github.com/repos/ros2/ros2_documentation/issues/5016
# Issue(title="fix group tag indent for ROSCon 2023 and 2024 contents.", number=5016)
# ---
# Closed
# mergify[bot]
# https://api.github.com/repos/ros2/ros2_documentation/issues/5015
# Issue(title="Clean up sentences (white space changes only) (backport #5001)", number=5015)
# ---
# Closed
# mergify[bot]
# https://api.github.com/repos/ros2/ros2_documentation/issues/5014
# Issue(title="Clean up sentences (white space changes only) (backport #5001)", number=5014)
# ---
# Closed
# mergify[bot]
# https://api.github.com/repos/ros2/ros2_documentation/issues/5013
# Issue(title="Add tutorial on Node Interfaces Template  Class (backport #4992)", number=5013)
# ---
# Closed
# mergify[bot]
# https://api.github.com/repos/ros2/ros2_documentation/issues/5012
# Issue(title="Add tutorial on Node Interfaces Template  Class (backport #4992)", number=5012)
# ---
# Closed
# mergify[bot]
# https://api.github.com/repos/ros2/ros2_documentation/issues/5011
# Issue(title="add documentation about spell check by codespell. (backport #5005)", number=5011)
# ---
# Closed
# mergify[bot]
# https://api.github.com/repos/ros2/ros2_documentation/issues/5010
# Issue(title="add documentation about spell check by codespell. (backport #5005)", number=5010)
# ---
# Closed
# mergify[bot]
# https://api.github.com/repos/ros2/ros2_documentation/issues/5009
# Issue(title="use ubuntu:jammy for container, otherwise doc8 fails to start. (backport #5007)", number=5009)
# ---
# Closed
# mergify[bot]
# https://api.github.com/repos/ros2/ros2_documentation/issues/5008
# Issue(title="use ubuntu:jammy for container, otherwise doc8 fails to start. (backport #5007)", number=5008)
# ---
# Closed
# fujitatomoya
# https://api.github.com/repos/ros2/ros2_documentation/issues/5007
# Issue(title="use ubuntu:jammy for container, otherwise doc8 fails to start.", number=5007)
# ---
# Closed
# fujitatomoya
# https://api.github.com/repos/ros2/ros2_documentation/issues/5006
# Issue(title="`make test` fails to start with using `devcontainer`.", number=5006)
# ---
# Closed
# fujitatomoya
# https://api.github.com/repos/ros2/ros2_documentation/issues/5005
# Issue(title="add documentation about spell check by codespell.", number=5005)
# ---
# OPEN
# fujitatomoya
# https://api.github.com/repos/ros2/ros2_documentation/issues/5004
# Issue(title="Requesting ROS 2 words for codespell ROS 2 dictionary support.", number=5004)
# ---
# Closed
# mergify[bot]
# https://api.github.com/repos/ros2/ros2_documentation/issues/5003
# Issue(title="Add ROS 1 to ROS 2 migration note for group parameter handling (backport #4983)", number=5003)
# ---
# Closed
# mergify[bot]
# https://api.github.com/repos/ros2/ros2_documentation/issues/5002
# Issue(title="Add ROS 1 to ROS 2 migration note for group parameter handling (backport #4983)", number=5002)
# ---
# Closed
# DLu
# https://api.github.com/repos/ros2/ros2_documentation/issues/5001
# Issue(title="Clean up sentences (white space changes only)", number=5001)
# ---
# Closed
# mergify[bot]
# https://api.github.com/repos/ros2/ros2_documentation/issues/5000
# Issue(title="automatic spellcheck by codespell for common misspellings. (backport #4997)", number=5000)
# ---
# Closed
# mergify[bot]
# https://api.github.com/repos/ros2/ros2_documentation/issues/4999
# Issue(title="automatic spellcheck by codespell for common misspellings. (backport #4997)", number=4999)
# ---
# OPEN
# fujitatomoya
# https://api.github.com/repos/ros2/ros2_documentation/issues/4998
# Issue(title="automatic spelling check by sphinx-spelling ext.", number=4998)
# ---
# Closed
# fujitatomoya
# https://api.github.com/repos/ros2/ros2_documentation/issues/4997
# Issue(title="automatic spellcheck by codespell for common misspellings.", number=4997)
# ---
# OPEN
# fujitatomoya
# https://api.github.com/repos/ros2/ros2_documentation/issues/4996
# Issue(title="apply one-sentence-per-line rule for rst files via github workflow.", number=4996)
# ---
# Closed
# mergify[bot]
# https://api.github.com/repos/ros2/ros2_documentation/issues/4995
# Issue(title="Suggested additions from contributor. (backport #4990)", number=4995)
# ---
# Closed
# mergify[bot]
# https://api.github.com/repos/ros2/ros2_documentation/issues/4994
# Issue(title="Suggested additions from contributor. (backport #4990)", number=4994)
# ---
# OPEN
# santiago-tapia
# https://api.github.com/repos/ros2/ros2_documentation/issues/4993
# Issue(title="Minimal service client implementation without using wait_until_future_complete", number=4993)
# ---
# Closed
# NickTziaros
# https://api.github.com/repos/ros2/ros2_documentation/issues/4992
# Issue(title="Add tutorial on Node Interfaces Template  Class", number=4992)
# ---
# Closed
# NickTziaros
# https://api.github.com/repos/ros2/ros2_documentation/issues/4991
# Issue(title="Added Tutorial on Node Interfaces Template Class", number=4991)
# ---
# Closed
# kscottz
# https://api.github.com/repos/ros2/ros2_documentation/issues/4990
# Issue(title="Suggested additions from contributor.", number=4990)
# ---
# OPEN
# clalancette
# https://api.github.com/repos/ros2/ros2_documentation/issues/4989
# Issue(title="Cleanup the Windows instructions for using conda/pixi.", number=4989)
# ---
# Closed
# EmmanuelMess
# https://api.github.com/repos/ros2/ros2_documentation/issues/4988
# Issue(title="Doxygen is missing for newer ros versions", number=4988)
# ---
# Closed
# pat92fr
# https://api.github.com/repos/ros2/ros2_documentation/issues/4987
# Issue(title="prototype of an action client response callback (update and revert)", number=4987)
# ---
# OPEN
# EmmanuelMess
# https://api.github.com/repos/ros2/ros2_documentation/issues/4986
# Issue(title="Add a warning to action doc that it cannot be created under ament_python", number=4986)
# ---
# OPEN
# EmmanuelMess
# https://api.github.com/repos/ros2/ros2_documentation/issues/4985
# Issue(title="Link to the API in the examples", number=4985)
# ---
# OPEN
# kscottz
# https://api.github.com/repos/ros2/ros2_documentation/issues/4984
# Issue(title="Strategies for YAML Message Generation Using ROS CLI", number=4984)
# ---
# Closed
# MariuszSzczepanikSpyrosoft
# https://api.github.com/repos/ros2/ros2_documentation/issues/4983
# Issue(title="Add ROS 1 to ROS 2 migration note for group parameter handling", number=4983)
# ---
# Closed
# mergify[bot]
# https://api.github.com/repos/ros2/ros2_documentation/issues/4982
# Issue(title="address mistyping detected by codespell checker. (backport #4980)", number=4982)
# ---
# Closed
# mergify[bot]
# https://api.github.com/repos/ros2/ros2_documentation/issues/4981
# Issue(title="address mistyping detected by codespell checker. (backport #4980)", number=4981)
# ---
# Closed
# fujitatomoya
# https://api.github.com/repos/ros2/ros2_documentation/issues/4980
# Issue(title="address mistyping detected by codespell checker.", number=4980)
# ---
# Closed
# mergify[bot]
# https://api.github.com/repos/ros2/ros2_documentation/issues/4979
# Issue(title="Remove underscored objects from rosbag_py tutorial (backport #4976)", number=4979)
# ---
# Closed
# mergify[bot]
# https://api.github.com/repos/ros2/ros2_documentation/issues/4978
# Issue(title="Remove underscored objects from rosbag_py tutorial (backport #4976)", number=4978)
# ---
# OPEN
# ahcorde
# https://api.github.com/repos/ros2/ros2_documentation/issues/4977
# Issue(title="Added zenoh security documention", number=4977)
# ---
# Closed
# rickwalder
# https://api.github.com/repos/ros2/ros2_documentation/issues/4976
# Issue(title="Remove underscored objects from rosbag_py tutorial", number=4976)
# ---
# Closed
# mergify[bot]
# https://api.github.com/repos/ros2/ros2_documentation/issues/4975
# Issue(title="Correct Kat Scott's role listing (backport #4967)", number=4975)
# ---
# Closed
# mergify[bot]
# https://api.github.com/repos/ros2/ros2_documentation/issues/4974
# Issue(title="Correct Kat Scott's role listing (backport #4967)", number=4974)
# ---
# Closed
# fujitatomoya
# https://api.github.com/repos/ros2/ros2_documentation/issues/4973
# Issue(title="suggest spin_all to migrate spinOnce to execute all available works i…", number=4973)
# ---
# Closed
# mergify[bot]
# https://api.github.com/repos/ros2/ros2_documentation/issues/4972
# Issue(title="Remove confusing services definition (backport #4970)", number=4972)
# ---
# Closed
# mergify[bot]
# https://api.github.com/repos/ros2/ros2_documentation/issues/4971
# Issue(title="Remove confusing services definition (backport #4970)", number=4971)
# ---
# Closed
# karaketir16
# https://api.github.com/repos/ros2/ros2_documentation/issues/4970
# Issue(title="Remove confusing services definition", number=4970)
# ---
# Closed
# mergify[bot]
# https://api.github.com/repos/ros2/ros2_documentation/issues/4969
# Issue(title="suggest spin_all to migrate spinOnce to execute all available works i… (backport #4966)", number=4969)
# ---
# Closed
# karaketir16
# https://api.github.com/repos/ros2/ros2_documentation/issues/4968
# Issue(title="Clarification needed: Should we avoid using services?", number=4968)
# ---
# Closed
# gbiggs
# https://api.github.com/repos/ros2/ros2_documentation/issues/4967
# Issue(title="Correct Kat Scott's role listing", number=4967)
# ---
# Closed
# fujitatomoya
# https://api.github.com/repos/ros2/ros2_documentation/issues/4966
# Issue(title="suggest spin_all to migrate spinOnce to execute all available works i…", number=4966)
# ---
# Closed
# Automationsala
# https://api.github.com/repos/ros2/ros2_documentation/issues/4965
# Issue(title="Unable to locate package ros-humble", number=4965)
# ---
# Closed
# mergify[bot]
# https://api.github.com/repos/ros2/ros2_documentation/issues/4964
# Issue(title="Improved-Dynamic-Discovery.rst: Fixing Bash Syntax (backport #4960)", number=4964)
# ---
# Closed
# mergify[bot]
# https://api.github.com/repos/ros2/ros2_documentation/issues/4963
# Issue(title="Update Launching-Multiple-Nodes.rst (backport #4961)", number=4963)
# ---
# Closed
# mergify[bot]
# https://api.github.com/repos/ros2/ros2_documentation/issues/4962
# Issue(title="Update Launching-Multiple-Nodes.rst (backport #4961)", number=4962)
# ---
# Closed
# studiareCS
# https://api.github.com/repos/ros2/ros2_documentation/issues/4961
# Issue(title="Update Launching-Multiple-Nodes.rst", number=4961)
# ---
# Closed
# TOTON95
# https://api.github.com/repos/ros2/ros2_documentation/issues/4960
# Issue(title="Improved-Dynamic-Discovery.rst: Fixing Bash Syntax", number=4960)
# ---
# Closed
# wouter-heerwegh
# https://api.github.com/repos/ros2/ros2_documentation/issues/4959
# Issue(title="ROS2 migration guide replaces spinOnce with spin_some", number=4959)
# ---
# Closed
# mergify[bot]
# https://api.github.com/repos/ros2/ros2_documentation/issues/4958
# Issue(title="build only selected packages to enable security. (backport #4890)", number=4958)
# ---
# Closed
# mergify[bot]
# https://api.github.com/repos/ros2/ros2_documentation/issues/4957
# Issue(title="build only selected packages to enable security. (backport #4890)", number=4957)
# ---
# Closed
# mergify[bot]
# https://api.github.com/repos/ros2/ros2_documentation/issues/4956
# Issue(title="add example how to use wildcards in parameter yaml file. (backport #4950)", number=4956)
# ---
# Closed
# mergify[bot]
# https://api.github.com/repos/ros2/ros2_documentation/issues/4955
# Issue(title="add example how to use wildcards in parameter yaml file. (backport #4950)", number=4955)
# ---
# Closed
# rpl-harrison-parkes
# https://api.github.com/repos/ros2/ros2_documentation/issues/4954
# Issue(title="Update Visualizing-ROS-2-Data-With-Foxglove-Studio.rst", number=4954)
# ---
# Closed
# mergify[bot]
# https://api.github.com/repos/ros2/ros2_documentation/issues/4953
# Issue(title="Add initial timeline for Kilted Kaiju (backport #4905)", number=4953)
# ---
# Closed
# mergify[bot]
# https://api.github.com/repos/ros2/ros2_documentation/issues/4952
# Issue(title="Add initial timeline for Kilted Kaiju (backport #4905)", number=4952)
# ---
# Closed
# julianmueller
# https://api.github.com/repos/ros2/ros2_documentation/issues/4951
# Issue(title="Missing quotes in doc for "Improved Dynamic Discovery"", number=4951)
# ---
# Closed
# fujitatomoya
# https://api.github.com/repos/ros2/ros2_documentation/issues/4950
# Issue(title="add example how to use wildcards in parameter yaml file.", number=4950)
# ---
# Closed
# christophebedard
# https://api.github.com/repos/ros2/ros2_documentation/issues/4949
# Issue(title="Fix title underline", number=4949)
# ---
# Closed
# mergify[bot]
# https://api.github.com/repos/ros2/ros2_documentation/issues/4948
# Issue(title="Correcting the name of the programming language (backport #4946)", number=4948)
# ---
# Closed
# mergify[bot]
# https://api.github.com/repos/ros2/ros2_documentation/issues/4947
# Issue(title="Correcting the name of the programming language (backport #4946)", number=4947)
# ---
# Closed
# ViktorCVS
# https://api.github.com/repos/ros2/ros2_documentation/issues/4946
# Issue(title="Correcting the name of the programming language", number=4946)
# ---
# Closed
# mergify[bot]
# https://api.github.com/repos/ros2/ros2_documentation/issues/4945
# Issue(title="add Extra Arguments for Component Manager. (backport #4904)", number=4945)
# ---
# Closed
# mergify[bot]
# https://api.github.com/repos/ros2/ros2_documentation/issues/4944
# Issue(title="add Extra Arguments for Component Manager. (backport #4904)", number=4944)
# ---
# Closed
# mergify[bot]
# https://api.github.com/repos/ros2/ros2_documentation/issues/4943
# Issue(title="Add note on how to block the release of select packages in a given repository (backport #4941)", number=4943)
# ---
# Closed
# mergify[bot]
# https://api.github.com/repos/ros2/ros2_documentation/issues/4942
# Issue(title="Add note on how to block the release of select packages in a given repository (backport #4941)", number=4942)
# ---
# Closed
# Yadunund
# https://api.github.com/repos/ros2/ros2_documentation/issues/4941
# Issue(title="Add note on how to block the release of select packages in a given repository", number=4941)
# ---
# Closed
# christophebedard
# https://api.github.com/repos/ros2/ros2_documentation/issues/4940
# Issue(title="Revert "Fix a typo in Writing-A-Simple-Cpp-Service-And-Client.rst (backport #4934)"", number=4940)
# ---
# Closed
# christophebedard
# https://api.github.com/repos/ros2/ros2_documentation/issues/4939
# Issue(title="Revert "Fix a typo in Writing-A-Simple-Cpp-Service-And-Client.rst (backport #4934)"", number=4939)
# ---
# Closed
# mergify[bot]
# https://api.github.com/repos/ros2/ros2_documentation/issues/4938
# Issue(title="Fix a typo in Writing-A-Simple-Cpp-Service-And-Client.rst (backport #4934)", number=4938)
# ---
# Closed
# mergify[bot]
# https://api.github.com/repos/ros2/ros2_documentation/issues/4937
# Issue(title="Fix a typo in Writing-A-Simple-Cpp-Service-And-Client.rst (backport #4934)", number=4937)
# ---
# Closed
# mergify[bot]
# https://api.github.com/repos/ros2/ros2_documentation/issues/4936
# Issue(title="move RTI Connext DDS installation doc under Install-Connext-Universit… (backport #4774)", number=4936)
# ---
# Closed
# mergify[bot]
# https://api.github.com/repos/ros2/ros2_documentation/issues/4935
# Issue(title="move RTI Connext DDS installation doc under Install-Connext-Universit… (backport #4774)", number=4935)
# ---
# Closed
# jihyeseo
# https://api.github.com/repos/ros2/ros2_documentation/issues/4934
# Issue(title="Fix a typo in Writing-A-Simple-Cpp-Service-And-Client.rst", number=4934)
# ---
# Closed
# mergify[bot]
# https://api.github.com/repos/ros2/ros2_documentation/issues/4933
# Issue(title="Update Colcon-Tutorial.rst (backport #4867)", number=4933)
# ---
# Closed
# mergify[bot]
# https://api.github.com/repos/ros2/ros2_documentation/issues/4932
# Issue(title="Update Colcon-Tutorial.rst (backport #4867)", number=4932)
# ---
# Closed
# mergify[bot]
# https://api.github.com/repos/ros2/ros2_documentation/issues/4931
# Issue(title="Rviz Panel Tutorial (backport #4869)", number=4931)
# ---
# Closed
# mergify[bot]
# https://api.github.com/repos/ros2/ros2_documentation/issues/4930
# Issue(title="Rviz Panel Tutorial (backport #4869)", number=4930)
# ---
# Closed
# jkaniuka
# https://api.github.com/repos/ros2/ros2_documentation/issues/4929
# Issue(title="Accessing parameters loaded from YAML file", number=4929)
# ---
# Closed
# fujitatomoya
# https://api.github.com/repos/ros2/ros2_documentation/issues/4928
# Issue(title="use bidirectional bridge in ros gz bridge tutorial.", number=4928)
# ---
# Closed
# wouter-heerwegh
# https://api.github.com/repos/ros2/ros2_documentation/issues/4927
# Issue(title="Parameter namespace usage", number=4927)
# ---
# OPEN
# Demonmasterlqx
# https://api.github.com/repos/ros2/ros2_documentation/issues/4926
# Issue(title="add cpp version for urdf_tutorial", number=4926)
# ---
# OPEN
# mosfet80
# https://api.github.com/repos/ros2/ros2_documentation/issues/4925
# Issue(title="Update Code-Style-Language-Versions.rst", number=4925)
# ---
# OPEN
# Yadunund
# https://api.github.com/repos/ros2/ros2_documentation/issues/4924
# Issue(title="Add a tutorial on Lifecycle nodes", number=4924)
# ---
# Closed
# mergify[bot]
# https://api.github.com/repos/ros2/ros2_documentation/issues/4923
# Issue(title="Update Debugging-Tf2-Problems.rst (backport #4921)", number=4923)
# ---
# Closed
# mergify[bot]
# https://api.github.com/repos/ros2/ros2_documentation/issues/4922
# Issue(title="Update Debugging-Tf2-Problems.rst (backport #4921)", number=4922)
# ---
# Closed
# Demonmasterlqx
# https://api.github.com/repos/ros2/ros2_documentation/issues/4921
# Issue(title="Update Debugging-Tf2-Problems.rst", number=4921)
# ---
# Closed
# Demonmasterlqx
# https://api.github.com/repos/ros2/ros2_documentation/issues/4920
# Issue(title="Update Debugging-Tf2-Problems.rst", number=4920)
# ---
# Closed
# mergify[bot]
# https://api.github.com/repos/ros2/ros2_documentation/issues/4919
# Issue(title="add explanation about component containers. (backport #4902)", number=4919)
# ---
# Closed
# mergify[bot]
# https://api.github.com/repos/ros2/ros2_documentation/issues/4918
# Issue(title="add explanation about component containers. (backport #4902)", number=4918)
# ---
# Closed
# fujitatomoya
# https://api.github.com/repos/ros2/ros2_documentation/issues/4917
# Issue(title="spin_until_future_complete should wait on future, but result.", number=4917)
# ---
# Closed
# Darkproduct
# https://api.github.com/repos/ros2/ros2_documentation/issues/4916
# Issue(title="Broken Tutorial "Beginner: Client libraries" / "Writing a simple service and client (C++)"", number=4916)
# ---
# Closed
# shadihh9
# https://api.github.com/repos/ros2/ros2_documentation/issues/4915
# Issue(title="access Script Console  Jenkins  lead to do rce build.ros2.org", number=4915)
# ---
# Closed
# cottsay
# https://api.github.com/repos/ros2/ros2_documentation/issues/4914
# Issue(title="Drop unsupported Python packages from instructions", number=4914)
# ---
# Closed
# apirek
# https://api.github.com/repos/ros2/ros2_documentation/issues/4913
# Issue(title="Ubuntu 22.04 is listed as supported platform for Jazzy", number=4913)
# ---
# Closed
# kscottz
# https://api.github.com/repos/ros2/ros2_documentation/issues/4912
# Issue(title="Ament Copyright Working Example", number=4912)
# ---
# Closed
# mergify[bot]
# https://api.github.com/repos/ros2/ros2_documentation/issues/4911
# Issue(title="[interim] Ament Lint CLI Utilities  (backport #4908)", number=4911)
# ---
# Closed
# mergify[bot]
# https://api.github.com/repos/ros2/ros2_documentation/issues/4910
# Issue(title="[interim] Ament Lint CLI Utilities  (backport #4908)", number=4910)
# ---
# OPEN
# alsora
# https://api.github.com/repos/ros2/ros2_documentation/issues/4909
# Issue(title="add working groups section and fill-in client library details", number=4909)
# ---
# Closed
# kscottz
# https://api.github.com/repos/ros2/ros2_documentation/issues/4908
# Issue(title="[interim] Ament Lint CLI Utilities ", number=4908)
# ---
# Closed
# mergify[bot]
# https://api.github.com/repos/ros2/ros2_documentation/issues/4907
# Issue(title="add how to use `ros2cli` with security enclaves. (backport #4900)", number=4907)
# ---
# Closed
# mergify[bot]
# https://api.github.com/repos/ros2/ros2_documentation/issues/4906
# Issue(title="add how to use `ros2cli` with security enclaves. (backport #4900)", number=4906)
# ---
# Closed
# cottsay
# https://api.github.com/repos/ros2/ros2_documentation/issues/4905
# Issue(title="Add initial timeline for Kilted Kaiju", number=4905)
# ---
# Closed
# fujitatomoya
# https://api.github.com/repos/ros2/ros2_documentation/issues/4904
# Issue(title="add Extra Arguments for Component Manager.", number=4904)
# ---
# OPEN
# santiago-tapia
# https://api.github.com/repos/ros2/ros2_documentation/issues/4903
# Issue(title="Tutorial for writing a service with an asynchronous client node", number=4903)
# ---
# Closed
# fujitatomoya
# https://api.github.com/repos/ros2/ros2_documentation/issues/4902
# Issue(title="add explanation about component containers.", number=4902)
# ---
# Closed
# fujitatomoya
# https://api.github.com/repos/ros2/ros2_documentation/issues/4901
# Issue(title="add explanation about component container types and options", number=4901)
# ---
# Closed
# fujitatomoya
# https://api.github.com/repos/ros2/ros2_documentation/issues/4900
# Issue(title="add how to use `ros2cli` with security enclaves.", number=4900)
# ---
# Closed
# mergify[bot]
# https://api.github.com/repos/ros2/ros2_documentation/issues/4899
# Issue(title="Add tutorial on integration testing (backport #4881)", number=4899)
# ---
# Closed
# mergify[bot]
# https://api.github.com/repos/ros2/ros2_documentation/issues/4898
# Issue(title="Add tutorial on integration testing (backport #4881)", number=4898)
# ---
# Closed
# mergify[bot]
# https://api.github.com/repos/ros2/ros2_documentation/issues/4897
# Issue(title="Mark Iron Irwini as end-of-life (backport #4894)", number=4897)
# ---
# Closed
# mergify[bot]
# https://api.github.com/repos/ros2/ros2_documentation/issues/4896
# Issue(title="Mark Iron Irwini as end-of-life (backport #4894)", number=4896)
# ---
# Closed
# mergify[bot]
# https://api.github.com/repos/ros2/ros2_documentation/issues/4895
# Issue(title="Mark Iron Irwini as end-of-life (backport #4894)", number=4895)
# ---
# Closed
# Yadunund
# https://api.github.com/repos/ros2/ros2_documentation/issues/4894
# Issue(title="Mark Iron Irwini as end-of-life", number=4894)
# ---
# Closed
# meetgandhi-dev
# https://api.github.com/repos/ros2/ros2_documentation/issues/4893
# Issue(title="Missing Dependency rti-connext-dds-6.0.1 in rosdep Installation while building jazzy from source", number=4893)
# ---
# Closed
# RobotBramhana
# https://api.github.com/repos/ros2/ros2_documentation/issues/4892
# Issue(title="Naming for the next release K", number=4892)
# ---
# Closed
# fujitatomoya
# https://api.github.com/repos/ros2/ros2_documentation/issues/4891
# Issue(title="Add explanation how to iterate with secured ROS 2 system via ros2cli", number=4891)
# ---
# Closed
# fujitatomoya
# https://api.github.com/repos/ros2/ros2_documentation/issues/4890
# Issue(title="build only selected packages to enable security.", number=4890)
# ---
# Closed
# mergify[bot]
# https://api.github.com/repos/ros2/ros2_documentation/issues/4889
# Issue(title="Add ROS Bosses to the list of distributions. (backport #4879)", number=4889)
# ---
# Closed
# mergify[bot]
# https://api.github.com/repos/ros2/ros2_documentation/issues/4888
# Issue(title="Add ROS Bosses to the list of distributions. (backport #4879)", number=4888)
# ---
# Closed
# mergify[bot]
# https://api.github.com/repos/ros2/ros2_documentation/issues/4887
# Issue(title="Add ROS Bosses to the list of distributions. (backport #4879)", number=4887)
# ---
# OPEN
# clalancette
# https://api.github.com/repos/ros2/ros2_documentation/issues/4886
# Issue(title="Add a page describing the ROS Boss role", number=4886)
# ---
# Closed
# mergify[bot]
# https://api.github.com/repos/ros2/ros2_documentation/issues/4885
# Issue(title="Document the colcon mixin repo (backport #4882)", number=4885)
# ---
# Closed
# mergify[bot]
# https://api.github.com/repos/ros2/ros2_documentation/issues/4884
# Issue(title="Document the colcon mixin repo (backport #4882)", number=4884)
# ---
# Closed
# mergify[bot]
# https://api.github.com/repos/ros2/ros2_documentation/issues/4883
# Issue(title="Document the colcon mixin repo (backport #4882)", number=4883)
# ---
# Closed
# Ryanf55
# https://api.github.com/repos/ros2/ros2_documentation/issues/4882
# Issue(title="Document the colcon mixin repo", number=4882)
# ---
# Closed
# abaeyens
# https://api.github.com/repos/ros2/ros2_documentation/issues/4881
# Issue(title="Add tutorial on integration testing", number=4881)
# ---
# OPEN
# Z223I
# https://api.github.com/repos/ros2/ros2_documentation/issues/4880
# Issue(title="Update Setup-ROS-2-with-VSCode-and-Docker-Container.rst", number=4880)
# ---
# Closed
# clalancette
# https://api.github.com/repos/ros2/ros2_documentation/issues/4879
# Issue(title="Add ROS Bosses to the list of distributions.", number=4879)
# ---
# Closed
# mergify[bot]
# https://api.github.com/repos/ros2/ros2_documentation/issues/4878
# Issue(title="Fixes to the RViz-Marker-Display-types tutorial. (backport #4875)", number=4878)
# ---
# Closed
# mergify[bot]
# https://api.github.com/repos/ros2/ros2_documentation/issues/4877
# Issue(title="Fixes to the RViz-Marker-Display-types tutorial. (backport #4875)", number=4877)
# ---
# Closed
# mergify[bot]
# https://api.github.com/repos/ros2/ros2_documentation/issues/4876
# Issue(title="Fixes to the RViz-Marker-Display-types tutorial. (backport #4875)", number=4876)
# ---
# Closed
# clalancette
# https://api.github.com/repos/ros2/ros2_documentation/issues/4875
# Issue(title="Fixes to the RViz-Marker-Display-types tutorial.", number=4875)
# ---
# OPEN
# kscottz
# https://api.github.com/repos/ros2/ros2_documentation/issues/4874
# Issue(title="White Space Cleanup Before Linting?", number=4874)
# ---
# Closed
# mergify[bot]
# https://api.github.com/repos/ros2/ros2_documentation/issues/4873
# Issue(title="Add RViz Marker DisplayTypes Tutorial (backport #4821)", number=4873)
# ---
# Closed
# mergify[bot]
# https://api.github.com/repos/ros2/ros2_documentation/issues/4872
# Issue(title="Add RViz Marker DisplayTypes Tutorial (backport #4821)", number=4872)
# ---
# Closed
# mergify[bot]
# https://api.github.com/repos/ros2/ros2_documentation/issues/4871
# Issue(title="Add RViz Marker DisplayTypes Tutorial (backport #4821)", number=4871)
# ---
# Closed
# Wwj180
# https://api.github.com/repos/ros2/ros2_documentation/issues/4870
# Issue(title="I have a problem to install ros2 on Ubuntu20.04 ", number=4870)
# ---
# Closed
# DLu
# https://api.github.com/repos/ros2/ros2_documentation/issues/4869
# Issue(title="Rviz Panel Tutorial", number=4869)
# ---
# Closed
# M61ss
# https://api.github.com/repos/ros2/ros2_documentation/issues/4868
# Issue(title="Update Creating-A-Workspace.rst", number=4868)
# ---
# Closed
# M61ss
# https://api.github.com/repos/ros2/ros2_documentation/issues/4867
# Issue(title="Update Colcon-Tutorial.rst", number=4867)
# ---
# Closed
# mergify[bot]
# https://api.github.com/repos/ros2/ros2_documentation/issues/4866
# Issue(title="Fix link for second day of lighting talks in ROSCon-Content.rst (backport #4863)", number=4866)
# ---
# Closed
# mergify[bot]
# https://api.github.com/repos/ros2/ros2_documentation/issues/4865
# Issue(title="Fix link for second day of lighting talks in ROSCon-Content.rst (backport #4863)", number=4865)
# ---
# Closed
# mergify[bot]
# https://api.github.com/repos/ros2/ros2_documentation/issues/4864
# Issue(title="Fix link for second day of lighting talks in ROSCon-Content.rst (backport #4863)", number=4864)
# ---
# Closed
# michalpelka
# https://api.github.com/repos/ros2/ros2_documentation/issues/4863
# Issue(title="Fix link for second day of lighting talks in ROSCon-Content.rst", number=4863)
# ---
# Closed
# mergify[bot]
# https://api.github.com/repos/ros2/ros2_documentation/issues/4862
# Issue(title="ROSCon 2024 Videos (backport #4859)", number=4862)
# ---
# Closed
# mergify[bot]
# https://api.github.com/repos/ros2/ros2_documentation/issues/4861
# Issue(title="ROSCon 2024 Videos (backport #4859)", number=4861)
# ---
# Closed
# mergify[bot]
# https://api.github.com/repos/ros2/ros2_documentation/issues/4860
# Issue(title="ROSCon 2024 Videos (backport #4859)", number=4860)
# ---
# Closed
# kscottz
# https://api.github.com/repos/ros2/ros2_documentation/issues/4859
# Issue(title="ROSCon 2024 Videos", number=4859)
# ---
# Closed
# mergify[bot]
# https://api.github.com/repos/ros2/ros2_documentation/issues/4858
# Issue(title="Update Understanding-ROS2-Topics.rst (backport #4855)", number=4858)
# ---
# Closed
# mergify[bot]
# https://api.github.com/repos/ros2/ros2_documentation/issues/4857
# Issue(title="Update Understanding-ROS2-Topics.rst (backport #4855)", number=4857)
# ---
# Closed
# mergify[bot]
# https://api.github.com/repos/ros2/ros2_documentation/issues/4856
# Issue(title="Update Understanding-ROS2-Topics.rst (backport #4855)", number=4856)
# ---
# Closed
# M61ss
# https://api.github.com/repos/ros2/ros2_documentation/issues/4855
# Issue(title="Update Understanding-ROS2-Topics.rst", number=4855)
# ---
# Closed
# mergify[bot]
# https://api.github.com/repos/ros2/ros2_documentation/issues/4854
# Issue(title="import package naming conventions (backport #4851)", number=4854)
# ---
# Closed
# mergify[bot]
# https://api.github.com/repos/ros2/ros2_documentation/issues/4853
# Issue(title="import package naming conventions (backport #4851)", number=4853)
# ---
# Closed
# mergify[bot]
# https://api.github.com/repos/ros2/ros2_documentation/issues/4852
# Issue(title="import package naming conventions (backport #4851)", number=4852)
# ---
# Closed
# tfoote
# https://api.github.com/repos/ros2/ros2_documentation/issues/4851
# Issue(title="import package naming conventions", number=4851)
# ---
# Closed
# mergify[bot]
# https://api.github.com/repos/ros2/ros2_documentation/issues/4850
# Issue(title="PMC: changed ahcorde affiliation (backport #4847)", number=4850)
# ---
# Closed
# mergify[bot]
# https://api.github.com/repos/ros2/ros2_documentation/issues/4849
# Issue(title="PMC: changed ahcorde affiliation (backport #4847)", number=4849)
# ---
# Closed
# mergify[bot]
# https://api.github.com/repos/ros2/ros2_documentation/issues/4848
# Issue(title="PMC: changed ahcorde affiliation (backport #4847)", number=4848)
# ---
# Closed
# ahcorde
# https://api.github.com/repos/ros2/ros2_documentation/issues/4847
# Issue(title="PMC: changed ahcorde affiliation", number=4847)
# ---
# Closed
# mergify[bot]
# https://api.github.com/repos/ros2/ros2_documentation/issues/4846
# Issue(title="[forwardport Rolling] Update Understanding-ROS2-Topics.rst (#4843) (backport #4844)", number=4846)
# ---
# Closed
# mergify[bot]
# https://api.github.com/repos/ros2/ros2_documentation/issues/4845
# Issue(title="[forwardport Rolling] Update Understanding-ROS2-Topics.rst (#4843) (backport #4844)", number=4845)
# ---
# Closed
# ahcorde
# https://api.github.com/repos/ros2/ros2_documentation/issues/4844
# Issue(title="[forwardport Rolling] Update Understanding-ROS2-Topics.rst (#4843)", number=4844)
# ---
# Closed
# M61ss
# https://api.github.com/repos/ros2/ros2_documentation/issues/4843
# Issue(title="Update Understanding-ROS2-Topics.rst", number=4843)
# ---
# Closed
# mergify[bot]
# https://api.github.com/repos/ros2/ros2_documentation/issues/4842
# Issue(title="Add tips about service client and rate (backport #4132)", number=4842)
# ---
# Closed
# mergify[bot]
# https://api.github.com/repos/ros2/ros2_documentation/issues/4841
# Issue(title="Add tips about service client and rate (backport #4132)", number=4841)
# ---
# Closed
# mergify[bot]
# https://api.github.com/repos/ros2/ros2_documentation/issues/4840
# Issue(title="Add tips about service client and rate (backport #4132)", number=4840)
# ---
# Closed
# mergify[bot]
# https://api.github.com/repos/ros2/ros2_documentation/issues/4839
# Issue(title="Update Custom-ROS2-Interfaces.rst (backport #4837)", number=4839)
# ---
# Closed
# mergify[bot]
# https://api.github.com/repos/ros2/ros2_documentation/issues/4838
# Issue(title="Update Custom-ROS2-Interfaces.rst (backport #4837)", number=4838)
# ---
# Closed
# Eric-SHENNONGSHI
# https://api.github.com/repos/ros2/ros2_documentation/issues/4837
# Issue(title="Update Custom-ROS2-Interfaces.rst", number=4837)
# ---
# Closed
# mergify[bot]
# https://api.github.com/repos/ros2/ros2_documentation/issues/4836
# Issue(title="Add do not ask developers directly (backport #4833)", number=4836)
# ---
# Closed
# mergify[bot]
# https://api.github.com/repos/ros2/ros2_documentation/issues/4835
# Issue(title="Add do not ask developers directly (backport #4833)", number=4835)
# ---
# Closed
# mergify[bot]
# https://api.github.com/repos/ros2/ros2_documentation/issues/4834
# Issue(title="Add do not ask developers directly (backport #4833)", number=4834)
# ---
# Closed
# tfoote
# https://api.github.com/repos/ros2/ros2_documentation/issues/4833
# Issue(title="Add do not ask developers directly", number=4833)
# ---
# Closed
# mergify[bot]
# https://api.github.com/repos/ros2/ros2_documentation/issues/4832
# Issue(title="Add cottsay to the ROS PMC list (backport #4829)", number=4832)
# ---
# Closed
# mergify[bot]
# https://api.github.com/repos/ros2/ros2_documentation/issues/4831
# Issue(title="Add cottsay to the ROS PMC list (backport #4829)", number=4831)
# ---
# Closed
# mergify[bot]
# https://api.github.com/repos/ros2/ros2_documentation/issues/4830
# Issue(title="Add cottsay to the ROS PMC list (backport #4829)", number=4830)
# ---
# Closed
# cottsay
# https://api.github.com/repos/ros2/ros2_documentation/issues/4829
# Issue(title="Add cottsay to the ROS PMC list", number=4829)
# ---
# Closed
# CursedRock17
# https://api.github.com/repos/ros2/ros2_documentation/issues/4828
# Issue(title="Deprecating tf2 C Headers", number=4828)
# ---
# Closed
# abaeyens
# https://api.github.com/repos/ros2/ros2_documentation/issues/4827
# Issue(title="Proposal to add intermediate tutorial on integration testing", number=4827)
# ---
# Closed
# mergify[bot]
# https://api.github.com/repos/ros2/ros2_documentation/issues/4826
# Issue(title="Update documentation for working with GurumDDS (backport #4823)", number=4826)
# ---
# Closed
# mergify[bot]
# https://api.github.com/repos/ros2/ros2_documentation/issues/4825
# Issue(title="Update documentation for working with GurumDDS (backport #4823)", number=4825)
# ---
# Closed
# mergify[bot]
# https://api.github.com/repos/ros2/ros2_documentation/issues/4824
# Issue(title="Update documentation for working with GurumDDS (backport #4823)", number=4824)
# ---
# Closed
# Hyunsoo0o0
# https://api.github.com/repos/ros2/ros2_documentation/issues/4823
# Issue(title="Update documentation for working with GurumDDS", number=4823)
# ---
# Closed
# Hyunsoo0o0
# https://api.github.com/repos/ros2/ros2_documentation/issues/4822
# Issue(title="Update documentation for working with GurumDDS", number=4822)
# ---
# Closed
# LeweC
# https://api.github.com/repos/ros2/ros2_documentation/issues/4821
# Issue(title="Add RViz Marker DisplayTypes Tutorial", number=4821)
# ---
# Closed
# mergify[bot]
# https://api.github.com/repos/ros2/ros2_documentation/issues/4820
# Issue(title="Update Understanding-ROS2-Topics.rst (backport #4803)", number=4820)
# ---
# Closed
# mergify[bot]
# https://api.github.com/repos/ros2/ros2_documentation/issues/4819
# Issue(title="Update Understanding-ROS2-Topics.rst (backport #4803)", number=4819)
# ---
# Closed
# mergify[bot]
# https://api.github.com/repos/ros2/ros2_documentation/issues/4818
# Issue(title="Update Understanding-ROS2-Topics.rst (backport #4803)", number=4818)
# ---
# Closed
# mergify[bot]
# https://api.github.com/repos/ros2/ros2_documentation/issues/4817
# Issue(title="Add example for migrating a Python package from ROS 1 to 2 (backport #4780)", number=4817)
# ---
# Closed
# mergify[bot]
# https://api.github.com/repos/ros2/ros2_documentation/issues/4816
# Issue(title="Add example for migrating a Python package from ROS 1 to 2 (backport #4780)", number=4816)
# ---
# Closed
# mergify[bot]
# https://api.github.com/repos/ros2/ros2_documentation/issues/4815
# Issue(title="Add example for migrating a Python package from ROS 1 to 2 (backport #4780)", number=4815)
# ---
# OPEN
# sloretz
# https://api.github.com/repos/ros2/ros2_documentation/issues/4814
# Issue(title="Add guide on determining if dependencies are available in ROS 2", number=4814)
# ---
# Closed
# sloretz
# https://api.github.com/repos/ros2/ros2_documentation/issues/4813
# Issue(title="Use context manager form of rclpy.init()", number=4813)
# ---
# Closed
# fujitatomoya
# https://api.github.com/repos/ros2/ros2_documentation/issues/4812
# Issue(title="Deprecate StaticSingleThreaded Executor.", number=4812)
# ---
# Closed
# mergify[bot]
# https://api.github.com/repos/ros2/ros2_documentation/issues/4811
# Issue(title="add how to build the doc with devcontainer. (backport #4757)", number=4811)
# ---
# Closed
# mergify[bot]
# https://api.github.com/repos/ros2/ros2_documentation/issues/4810
# Issue(title="add how to build the doc with devcontainer. (backport #4757)", number=4810)
# ---
# Closed
# mergify[bot]
# https://api.github.com/repos/ros2/ros2_documentation/issues/4809
# Issue(title="add how to build the doc with devcontainer. (backport #4757)", number=4809)
# ---
# Closed
# mergify[bot]
# https://api.github.com/repos/ros2/ros2_documentation/issues/4808
# Issue(title="Add Dharini to Committers (backport #4805)", number=4808)
# ---
# Closed
# mergify[bot]
# https://api.github.com/repos/ros2/ros2_documentation/issues/4807
# Issue(title="Add Dharini to Committers (backport #4805)", number=4807)
# ---
# Closed
# mergify[bot]
# https://api.github.com/repos/ros2/ros2_documentation/issues/4806
# Issue(title="Add Dharini to Committers (backport #4805)", number=4806)
# ---
# Closed
# quarkytale
# https://api.github.com/repos/ros2/ros2_documentation/issues/4805
# Issue(title="Add Dharini to Committers", number=4805)
# ---
# OPEN
# EliottFerry
# https://api.github.com/repos/ros2/ros2_documentation/issues/4804
# Issue(title="Update Custom-ROS2-Interfaces.rst", number=4804)
# ---
# Closed
# mnhaqq
# https://api.github.com/repos/ros2/ros2_documentation/issues/4803
# Issue(title="Update Understanding-ROS2-Topics.rst", number=4803)
# ---
# Closed
# mergify[bot]
# https://api.github.com/repos/ros2/ros2_documentation/issues/4802
# Issue(title="Add option to wait for two subscriptions  (backport #4674)", number=4802)
# ---
# Closed
# mergify[bot]
# https://api.github.com/repos/ros2/ros2_documentation/issues/4801
# Issue(title="Add option to wait for two subscriptions  (backport #4674)", number=4801)
# ---
# Closed
# mergify[bot]
# https://api.github.com/repos/ros2/ros2_documentation/issues/4800
# Issue(title="Add option to wait for two subscriptions  (backport #4674)", number=4800)
# ---
# Closed
# mergify[bot]
# https://api.github.com/repos/ros2/ros2_documentation/issues/4799
# Issue(title="Remove obsolete RQt source installation instructions. (backport #4796)", number=4799)
# ---
# Closed
# mergify[bot]
# https://api.github.com/repos/ros2/ros2_documentation/issues/4798
# Issue(title="Remove obsolete RQt source installation instructions. (backport #4796)", number=4798)
# ---
# Closed
# mergify[bot]
# https://api.github.com/repos/ros2/ros2_documentation/issues/4797
# Issue(title="Remove obsolete RQt source installation instructions. (backport #4796)", number=4797)
# ---
# Closed
# clalancette
# https://api.github.com/repos/ros2/ros2_documentation/issues/4796
# Issue(title="Remove obsolete RQt source installation instructions.", number=4796)
# ---
# OPEN
# tedzards509
# https://api.github.com/repos/ros2/ros2_documentation/issues/4795
# Issue(title="Add workaround for building on Fedora", number=4795)
# ---
# Closed
# mergify[bot]
# https://api.github.com/repos/ros2/ros2_documentation/issues/4794
# Issue(title="Split ROS 1 -> 2 C++ page into a reference page and a tutorial page (backport #4779)", number=4794)
# ---
# Closed
# mergify[bot]
# https://api.github.com/repos/ros2/ros2_documentation/issues/4793
# Issue(title="Split ROS 1 -> 2 C++ page into a reference page and a tutorial page (backport #4779)", number=4793)
# ---
# Closed
# mergify[bot]
# https://api.github.com/repos/ros2/ros2_documentation/issues/4792
# Issue(title="Split ROS 1 -> 2 C++ page into a reference page and a tutorial page (backport #4779)", number=4792)
# ---
# Closed
# mergify[bot]
# https://api.github.com/repos/ros2/ros2_documentation/issues/4791
# Issue(title="Alphabetize PMC by last name (backport #4788)", number=4791)
# ---
# Closed
# mergify[bot]
# https://api.github.com/repos/ros2/ros2_documentation/issues/4790
# Issue(title="Alphabetize PMC by last name (backport #4788)", number=4790)
# ---
# Closed
# mergify[bot]
# https://api.github.com/repos/ros2/ros2_documentation/issues/4789
# Issue(title="Alphabetize PMC by last name (backport #4788)", number=4789)
# ---
# Closed
# audrow
# https://api.github.com/repos/ros2/ros2_documentation/issues/4788
# Issue(title="Alphabetize PMC by last name", number=4788)
# ---
# Closed
# mergify[bot]
# https://api.github.com/repos/ros2/ros2_documentation/issues/4787
# Issue(title="Add Audrow to PMC (backport #4784)", number=4787)
# ---
# Closed
# mergify[bot]
# https://api.github.com/repos/ros2/ros2_documentation/issues/4786
# Issue(title="Add Audrow to PMC (backport #4784)", number=4786)
# ---
# Closed
# mergify[bot]
# https://api.github.com/repos/ros2/ros2_documentation/issues/4785
# Issue(title="Add Audrow to PMC (backport #4784)", number=4785)
# ---
# Closed
# audrow
# https://api.github.com/repos/ros2/ros2_documentation/issues/4784
# Issue(title="Add Audrow to PMC", number=4784)
# ---
# Closed
# mergify[bot]
# https://api.github.com/repos/ros2/ros2_documentation/issues/4783
# Issue(title="Move package.xml format 1 to 2 migration to its own page (backport #4778)", number=4783)
# ---
# Closed
# mergify[bot]
# https://api.github.com/repos/ros2/ros2_documentation/issues/4782
# Issue(title="Move package.xml format 1 to 2 migration to its own page (backport #4778)", number=4782)
# ---
# Closed
# mergify[bot]
# https://api.github.com/repos/ros2/ros2_documentation/issues/4781
# Issue(title="Move package.xml format 1 to 2 migration to its own page (backport #4778)", number=4781)
# ---
# Closed
# sloretz
# https://api.github.com/repos/ros2/ros2_documentation/issues/4780
# Issue(title="Add example for migrating a Python package from ROS 1 to 2", number=4780)
# ---
# Closed
# sloretz
# https://api.github.com/repos/ros2/ros2_documentation/issues/4779
# Issue(title="Split ROS 1 -> 2 C++ page into a reference page and a tutorial page", number=4779)
# ---
# Closed
# sloretz
# https://api.github.com/repos/ros2/ros2_documentation/issues/4778
# Issue(title="Move package.xml format 1 to 2 migration to its own page", number=4778)
# ---
# Closed
# mergify[bot]
# https://api.github.com/repos/ros2/ros2_documentation/issues/4777
# Issue(title="Polish the ROS 1 -> 2 CMake instructions (backport #4767)", number=4777)
# ---
# Closed
# mergify[bot]
# https://api.github.com/repos/ros2/ros2_documentation/issues/4776
# Issue(title="Polish the ROS 1 -> 2 CMake instructions (backport #4767)", number=4776)
# ---
# Closed
# mergify[bot]
# https://api.github.com/repos/ros2/ros2_documentation/issues/4775
# Issue(title="Polish the ROS 1 -> 2 CMake instructions (backport #4767)", number=4775)
# ---
# Closed
# fujitatomoya
# https://api.github.com/repos/ros2/ros2_documentation/issues/4774
# Issue(title="move RTI Connext DDS installation doc under Install-Connext-Universit…", number=4774)
# ---
# Closed
# mergify[bot]
# https://api.github.com/repos/ros2/ros2_documentation/issues/4773
# Issue(title="Update Ada client library status for jazzy (backport #4746)", number=4773)
# ---
# Closed
# mergify[bot]
# https://api.github.com/repos/ros2/ros2_documentation/issues/4772
# Issue(title="Update Ada client library status for jazzy (backport #4746)", number=4772)
# ---
# Closed
# mergify[bot]
# https://api.github.com/repos/ros2/ros2_documentation/issues/4771
# Issue(title="Update Ada client library status for jazzy (backport #4746)", number=4771)
# ---
# Closed
# mergify[bot]
# https://api.github.com/repos/ros2/ros2_documentation/issues/4770
# Issue(title="Cross-Vendor communication is not guaranteed by design. (backport #4736)", number=4770)
# ---
# Closed
# mergify[bot]
# https://api.github.com/repos/ros2/ros2_documentation/issues/4769
# Issue(title="Cross-Vendor communication is not guaranteed by design. (backport #4736)", number=4769)
# ---
# Closed
# mergify[bot]
# https://api.github.com/repos/ros2/ros2_documentation/issues/4768
# Issue(title="Cross-Vendor communication is not guaranteed by design. (backport #4736)", number=4768)
# ---
# Closed
# sloretz
# https://api.github.com/repos/ros2/ros2_documentation/issues/4767
# Issue(title="Polish the ROS 1 -> 2 CMake instructions", number=4767)
# ---
# OPEN
# Ryanf55
# https://api.github.com/repos/ros2/ros2_documentation/issues/4766
# Issue(title="Document editing/debugging process in VSCode for C++ and Python when developing with the standard ROS toolchain.", number=4766)
# ---
# Closed
# mergify[bot]
# https://api.github.com/repos/ros2/ros2_documentation/issues/4765
# Issue(title="Add more explanation about PushRosNamespace action (backport #4679)", number=4765)
# ---
# Closed
# mergify[bot]
# https://api.github.com/repos/ros2/ros2_documentation/issues/4764
# Issue(title="Add more explanation about PushRosNamespace action (backport #4679)", number=4764)
# ---
# Closed
# mergify[bot]
# https://api.github.com/repos/ros2/ros2_documentation/issues/4763
# Issue(title="New Bindings for ROS2  (backport #4751)", number=4763)
# ---
# Closed
# mergify[bot]
# https://api.github.com/repos/ros2/ros2_documentation/issues/4762
# Issue(title="New Bindings for ROS2  (backport #4751)", number=4762)
# ---
# Closed
# mergify[bot]
# https://api.github.com/repos/ros2/ros2_documentation/issues/4761
# Issue(title="New Bindings for ROS2  (backport #4751)", number=4761)
# ---
# Closed
# mergify[bot]
# https://api.github.com/repos/ros2/ros2_documentation/issues/4760
# Issue(title="Fix a broken link in Ubuntu-Install-Debs.rst (backport #4759)", number=4760)
# ---
# Closed
# sukhodolin
# https://api.github.com/repos/ros2/ros2_documentation/issues/4759
# Issue(title="Fix a broken link in Ubuntu-Install-Debs.rst", number=4759)
# ---
# Closed
# aenoca
# https://api.github.com/repos/ros2/ros2_documentation/issues/4758
# Issue(title="Launch tutorial for Humble error", number=4758)
# ---
# Closed
# fujitatomoya
# https://api.github.com/repos/ros2/ros2_documentation/issues/4757
# Issue(title="add how to build the doc with devcontainer.", number=4757)
# ---
# Closed
# mergify[bot]
# https://api.github.com/repos/ros2/ros2_documentation/issues/4756
# Issue(title="Use URL hyperlinks for PMC affiliation and github handle. (backport #4745)", number=4756)
# ---
# Closed
# mergify[bot]
# https://api.github.com/repos/ros2/ros2_documentation/issues/4755
# Issue(title="Use URL hyperlinks for PMC affiliation and github handle. (backport #4745)", number=4755)
# ---
# Closed
# mergify[bot]
# https://api.github.com/repos/ros2/ros2_documentation/issues/4754
# Issue(title="Use URL hyperlinks for PMC affiliation and github handle. (backport #4745)", number=4754)
# ---
# Closed
# zanxueyan
# https://api.github.com/repos/ros2/ros2_documentation/issues/4753
# Issue(title="Use VS2022 development project in windows, release project times error", number=4753)
# ---
# Closed
# Ken-Andre
# https://api.github.com/repos/ros2/ros2_documentation/issues/4752
# Issue(title="Update Colcon-Tutorial.rst", number=4752)
# ---
# Closed
# harunkurtdev
# https://api.github.com/repos/ros2/ros2_documentation/issues/4751
# Issue(title="New Bindings for ROS2 ", number=4751)
# ---
# Closed
# mergify[bot]
# https://api.github.com/repos/ros2/ros2_documentation/issues/4750
# Issue(title="Update Links in Related Projects (backport #4747)", number=4750)
# ---
# Closed
# mergify[bot]
# https://api.github.com/repos/ros2/ros2_documentation/issues/4749
# Issue(title="Update Links in Related Projects (backport #4747)", number=4749)
# ---
# Closed
# mergify[bot]
# https://api.github.com/repos/ros2/ros2_documentation/issues/4748
# Issue(title="Update Links in Related Projects (backport #4747)", number=4748)
# ---
# Closed
# Amronos
# https://api.github.com/repos/ros2/ros2_documentation/issues/4747
# Issue(title="Update Links in Related Projects", number=4747)
# ---
# Closed
# mosteo
# https://api.github.com/repos/ros2/ros2_documentation/issues/4746
# Issue(title="Update Ada client library status for jazzy", number=4746)
# ---
# Closed
# fujitatomoya
# https://api.github.com/repos/ros2/ros2_documentation/issues/4745
# Issue(title="Use URL hyperlinks for PMC affiliation and github handle.", number=4745)
# ---
# Closed
# mergify[bot]
# https://api.github.com/repos/ros2/ros2_documentation/issues/4744
# Issue(title="Add scpeters to governance doc as committer (backport #4741)", number=4744)
# ---
# Closed
# mergify[bot]
# https://api.github.com/repos/ros2/ros2_documentation/issues/4743
# Issue(title="Add scpeters to governance doc as committer (backport #4741)", number=4743)
# ---
# Closed
# mergify[bot]
# https://api.github.com/repos/ros2/ros2_documentation/issues/4742
# Issue(title="Add scpeters to governance doc as committer (backport #4741)", number=4742)
# ---
# Closed
# scpeters
# https://api.github.com/repos/ros2/ros2_documentation/issues/4741
# Issue(title="Add scpeters to governance doc as committer", number=4741)
# ---
# Closed
# mergify[bot]
# https://api.github.com/repos/ros2/ros2_documentation/issues/4740
# Issue(title="Add myself as a PMC member to the governance doc. (backport #4737)", number=4740)
# ---
# Closed
# mergify[bot]
# https://api.github.com/repos/ros2/ros2_documentation/issues/4739
# Issue(title="Add myself as a PMC member to the governance doc. (backport #4737)", number=4739)
# ---
# Closed
# mergify[bot]
# https://api.github.com/repos/ros2/ros2_documentation/issues/4738
# Issue(title="Add myself as a PMC member to the governance doc. (backport #4737)", number=4738)
# ---
# Closed
# nuclearsandwich
# https://api.github.com/repos/ros2/ros2_documentation/issues/4737
# ...
# Issue(title="Remove aka.ms/ros in rolling", number=4121)
# ---
# Closed
# ooeygui
# https://api.github.com/repos/ros2/ros2_documentation/issues/4120
# Issue(title="Remove aka.ms/ros documentation", number=4120)
# ---
# Closed
# mergify[bot]
# https://api.github.com/repos/ros2/ros2_documentation/issues/4119
# Issue(title="Use classic PAT generation (backport #4117)", number=4119)
# ---
# Closed
# mergify[bot]
# https://api.github.com/repos/ros2/ros2_documentation/issues/4118
# Issue(title="Use classic PAT generation (backport #4117)", number=4118)
# ---
# Closed
# Ryanf55
# https://api.github.com/repos/ros2/ros2_documentation/issues/4117
# Issue(title="Use classic PAT generation", number=4117)
# ---
# Closed
# arjo129
# https://api.github.com/repos/ros2/ros2_documentation/issues/4116
# Issue(title="Document changes in the char type interface for rclpy.", number=4116)
# ---
# Closed
# mergify[bot]
# https://api.github.com/repos/ros2/ros2_documentation/issues/4115
# Issue(title="update release note for Jazzy, rclcpp type support handles. (backport #4102)", number=4115)
# ---
# Closed
# mergify[bot]
# https://api.github.com/repos/ros2/ros2_documentation/issues/4114
# Issue(title="update release note for Jazzy, rclcpp type support handles. (backport #4102)", number=4114)
# ---
# Closed
# mergify[bot]
# https://api.github.com/repos/ros2/ros2_documentation/issues/4113
# Issue(title="Remove duplicate argument to `ros2 pkg create` in tutorial page (#4103) (backport #4104)", number=4113)
# ---
# Closed
# mergify[bot]
# https://api.github.com/repos/ros2/ros2_documentation/issues/4112
# Issue(title="Remove duplicate argument to `ros2 pkg create` in tutorial page (#4103) (backport #4104)", number=4112)
# ---
# Closed
# mergify[bot]
# https://api.github.com/repos/ros2/ros2_documentation/issues/4111
# Issue(title="Fix typo in call to `get_clock` (#4099) (backport #4105)", number=4111)
# ---
# Closed
# mergify[bot]
# https://api.github.com/repos/ros2/ros2_documentation/issues/4110
# Issue(title="Fix typo in call to `get_clock` (#4099) (backport #4105)", number=4110)
# ---
# Closed
# mergify[bot]
# https://api.github.com/repos/ros2/ros2_documentation/issues/4109
# Issue(title="Constrain sphinxcontrib-applehelp. (backport #4107)", number=4109)
# ---
# Closed
# mergify[bot]
# https://api.github.com/repos/ros2/ros2_documentation/issues/4108
# Issue(title="Constrain sphinxcontrib-applehelp. (backport #4107)", number=4108)
# ---
# Closed
# clalancette
# https://api.github.com/repos/ros2/ros2_documentation/issues/4107
# Issue(title="Constrain sphinxcontrib-applehelp.", number=4107)
# ---
# Closed
# DLu
# https://api.github.com/repos/ros2/ros2_documentation/issues/4106
# Issue(title="Writing a Composable Node (C++) Tutorial", number=4106)
# ---
# Closed
# ivanperez-keera
# https://api.github.com/repos/ros2/ros2_documentation/issues/4105
# Issue(title="Fix typo in call to `get_clock` (#4099)", number=4105)
# ---
# Closed
# ivanperez-keera
# https://api.github.com/repos/ros2/ros2_documentation/issues/4104
# Issue(title="Remove duplicate argument to `ros2 pkg create` in tutorial page (#4103)", number=4104)
# ---
# Closed
# ivanperez-keera
# https://api.github.com/repos/ros2/ros2_documentation/issues/4103
# Issue(title="Tutorial mentions license argument twice in call to `ros2 pkg create`", number=4103)
# ---
# Closed
# fujitatomoya
# https://api.github.com/repos/ros2/ros2_documentation/issues/4102
# Issue(title="update release note for Jazzy, rclcpp type support handles.", number=4102)
# ---
# Closed
# mergify[bot]
# https://api.github.com/repos/ros2/ros2_documentation/issues/4101
# Issue(title="add Jazzy release note for "--log-file-name" command line argument. (backport #4087)", number=4101)
# ---
# Closed
# mergify[bot]
# https://api.github.com/repos/ros2/ros2_documentation/issues/4100
# Issue(title="add Jazzy release note for "--log-file-name" command line argument. (backport #4087)", number=4100)
# ---
# Closed
# mlanas
# https://api.github.com/repos/ros2/ros2_documentation/issues/4099
# Issue(title="Typo on log demo code example", number=4099)
# ---
# Closed
# mergify[bot]
# https://api.github.com/repos/ros2/ros2_documentation/issues/4098
# Issue(title="Fixing linking errors in Working-Groups.rst (backport #4096)", number=4098)
# ---
# Closed
# mergify[bot]
# https://api.github.com/repos/ros2/ros2_documentation/issues/4097
# Issue(title="Fixing linking errors in Working-Groups.rst (backport #4096)", number=4097)
# ---
# Closed
# knmcguire
# https://api.github.com/repos/ros2/ros2_documentation/issues/4096
# Issue(title="Fixing linking errors in Working-Groups.rst", number=4096)
# ---
# Closed
# songyuc
# https://api.github.com/repos/ros2/ros2_documentation/issues/4095
# Issue(title="Inquiry about Windows support for examining network traffic tutorial", number=4095)
# ---
# Closed
# BenBlumer
# https://api.github.com/repos/ros2/ros2_documentation/issues/4094
# Issue(title="Update Colcon-Tutorial.rst", number=4094)
# ---
# Closed
# scpeters
# https://api.github.com/repos/ros2/ros2_documentation/issues/4093
# Issue(title="macOS rolling: don't need tinyxml", number=4093)
# ---
# Closed
# mergify[bot]
# https://api.github.com/repos/ros2/ros2_documentation/issues/4092
# Issue(title="macOS: use tinyxml1 formula (backport #4091)", number=4092)
# ---
# Closed
# scpeters
# https://api.github.com/repos/ros2/ros2_documentation/issues/4091
# Issue(title="macOS: use tinyxml1 formula", number=4091)
# ---
# Closed
# mergify[bot]
# https://api.github.com/repos/ros2/ros2_documentation/issues/4090
# Issue(title="[Fix] clarify the compile-time composition behavior. (backport #4088)", number=4090)
# ---
# Closed
# mergify[bot]
# https://api.github.com/repos/ros2/ros2_documentation/issues/4089
# Issue(title="[Fix] clarify the compile-time composition behavior. (backport #4088)", number=4089)
# ---
# Closed
# ZhenshengLee
# https://api.github.com/repos/ros2/ros2_documentation/issues/4088
# Issue(title="[Fix] clarify the compile-time composition behavior.", number=4088)
# ---
# Closed
# fujitatomoya
# https://api.github.com/repos/ros2/ros2_documentation/issues/4087
# Issue(title="add doc for "--log-file-name" command line argument.", number=4087)
# ---
# Closed
# mergify[bot]
# https://api.github.com/repos/ros2/ros2_documentation/issues/4086
# Issue(title="Drop matplotlib from skipped keys during RHEL install (backport #4085)", number=4086)
# ---
# Closed
# cottsay
# https://api.github.com/repos/ros2/ros2_documentation/issues/4085
# Issue(title="Drop matplotlib from skipped keys during RHEL install", number=4085)
# ---
# Closed
# cottsay
# https://api.github.com/repos/ros2/ros2_documentation/issues/4084
# Issue(title="Drop assimp from skipped keys during RHEL install", number=4084)
# ---
# Closed
# samdarwisch
# https://api.github.com/repos/ros2/ros2_documentation/issues/4079
# Issue(title="[Windows & ros2-humble-20231122-windows-release-amd64]", number=4079)
# ---
# OPEN
# SammyRamone
# https://api.github.com/repos/ros2/ros2_documentation/issues/4061
# Issue(title="Update docs for configuring logging formats (espcially for use with ros2 launch)", number=4061)
# ---
# Closed
# FelipeGdM
# https://api.github.com/repos/ros2/ros2_documentation/issues/4041
# Issue(title="Migrate std::bind calls to lambda expressions", number=4041)
# ---
# Closed
# LeweC
# https://api.github.com/repos/ros2/ros2_documentation/issues/4040
# Issue(title="Add RViz UserGuide", number=4040)
# ---
# Closed
# julienthevenoz
# https://api.github.com/repos/ros2/ros2_documentation/issues/3986
# Issue(title="Reading from a bag file (C++) : small incoherence with basic tutorial ROS2 bag", number=3986)
# ---
# Closed
# songyuc
# https://api.github.com/repos/ros2/ros2_documentation/issues/3960
# Issue(title="Undefined 'now' variable in 'turtle_tf2_listener.py' tutorial", number=3960)
# ---
# Closed
# DLu
# https://api.github.com/repos/ros2/ros2_documentation/issues/3952
# Issue(title="URDF Sim Tutorial", number=3952)
# ---
# OPEN
# lucasw
# https://api.github.com/repos/ros2/ros2_documentation/issues/3949
# Issue(title="Confusing EOL boilerplate on pages about newer releases", number=3949)
# ---
# Closed
# fujitatomoya
# https://api.github.com/repos/ros2/ros2_documentation/issues/3921
# Issue(title="Do not drop future returned by async_send_goal.", number=3921)
# ---
# Closed
# songyuc
# https://api.github.com/repos/ros2/ros2_documentation/issues/3910
# Issue(title="[ERROR] [launch]: Caught exception in launch (see debug for traceback): "package 'turtle_tf2_py' not found, searching: ['D:\\\\launch\\\\launch_ws\\\\install', 'C:\\\\dev\\\\ros2_iron']"", number=3910)
# ---
# Closed
# LeweC
# https://api.github.com/repos/ros2/ros2_documentation/issues/3908
# Issue(title="Adding RViz tutorials", number=3908)
# ---
# Closed
# LeweC
# https://api.github.com/repos/ros2/ros2_documentation/issues/3864
# Issue(title="rviz plugin tutorial", number=3864)
# ---
# OPEN
# christophebedard
# https://api.github.com/repos/ros2/ros2_documentation/issues/3762
# Issue(title="Create rmw implementation tutorial", number=3762)
# ---
# OPEN
# cccccmake
# https://api.github.com/repos/ros2/ros2_documentation/issues/3761
# Issue(title="incorrect command in tutorial", number=3761)
# ---
# Closed
# hellantos
# https://api.github.com/repos/ros2/ros2_documentation/issues/3759
# Issue(title="Add how to guide for vendoring a non cmake package with ament_cmake", number=3759)
# ---
# Closed
# omichel
# https://api.github.com/repos/ros2/ros2_documentation/issues/3742
# Issue(title="Fix colcon python warnings", number=3742)
# ---
# OPEN
# cychitivav
# https://api.github.com/repos/ros2/ros2_documentation/issues/3678
# Issue(title="Multi-language support and management", number=3678)
# ---
# Closed
# vkuehn
# https://api.github.com/repos/ros2/ros2_documentation/issues/3664
# Issue(title="Setup-ROS-2-with-VSCode-and-Docker-Container.rst needs a review", number=3664)
# ---
# Closed
# Yadunund
# https://api.github.com/repos/ros2/ros2_documentation/issues/3633
# Issue(title="Cross compile tutorial relies on deprecated tooling?", number=3633)
# ---
# Closed
# FelipeGdM
# https://api.github.com/repos/ros2/ros2_documentation/issues/3618
# Issue(title="Use of std::bind in C++ code examples", number=3618)
# ---
# Closed
# fujitatomoya
# https://api.github.com/repos/ros2/ros2_documentation/issues/3573
# Issue(title="RTI Connext DDS installation procedure needs to be reorganized", number=3573)
# ---
# Closed
# DLu
# https://api.github.com/repos/ros2/ros2_documentation/issues/3384
# Issue(title="Building a custom rviz display", number=3384)
# ---
# OPEN
# EricCousineau-TRI
# https://api.github.com/repos/ros2/ros2_documentation/issues/3373
# Issue(title="Should document nuances for CMake `ctest` considerations - e.g. not depending on install tree for same package", number=3373)
# ---
# Closed
# knmcguire
# https://api.github.com/repos/ros2/ros2_documentation/issues/3340
# Issue(title="Simulation tutorial still advises ignition commands", number=3340)
# ---
# OPEN
# HenryInUtah
# https://api.github.com/repos/ros2/ros2_documentation/issues/3338
# Issue(title="Install Qt5 Directions need attention", number=3338)
# ---
# Closed
# audrow
# https://api.github.com/repos/ros2/ros2_documentation/issues/3334
# Issue(title="Revert "Revert "adding API change for spin_until_complete""", number=3334)
# ---
# Closed
# MRicoIE2CS
# https://api.github.com/repos/ros2/ros2_documentation/issues/3327
# Issue(title="Add ROS 2 CLI module to Fast DDS Discovery Server Tutorial", number=3327)
# ---
# Closed
# Mario-DL
# https://api.github.com/repos/ros2/ros2_documentation/issues/3318
# Issue(title="Security Deployment Guidelines Tutorial", number=3318)
# ---
# Closed
# sloretz
# https://api.github.com/repos/ros2/ros2_documentation/issues/3299
# Issue(title="Rough outline of ROS 1 to ROS 2 porting documentation", number=3299)
# ---
# Closed
# fujitatomoya
# https://api.github.com/repos/ros2/ros2_documentation/issues/3288
# Issue(title="Cross-Distro/Vendor communication in ROS 2", number=3288)
# ---
# Closed
# jodle001
# https://api.github.com/repos/ros2/ros2_documentation/issues/3242
# Issue(title="Documentation for ros2 rviz panel plugin", number=3242)
# ---
# Closed
# RFRIEDM-Trimble
# https://api.github.com/repos/ros2/ros2_documentation/issues/3237
# Issue(title="[rolling] Clarify usage of on_parameter_event", number=3237)
# ---
# OPEN
# RFRIEDM-Trimble
# https://api.github.com/repos/ros2/ros2_documentation/issues/3191
# Issue(title="ROS2 docs still recommend usage of deprecated ament_export_include_directories, _definitions, _libraries, _link_flags", number=3191)
# ---
# OPEN
# emersonknapp
# https://api.github.com/repos/ros2/ros2_documentation/issues/3167
# Issue(title="Windows 10 Instructions minor issues - openssl version, visual studio version", number=3167)
# ---
# Closed
# clalancette
# https://api.github.com/repos/ros2/ros2_documentation/issues/3149
# Issue(title="Documentation on steps to do a stable ROS 2 distribution patch release", number=3149)
# ---
# Closed
# Klarinemend
# https://api.github.com/repos/ros2/ros2_documentation/issues/3080
# Issue(title="Problems with Using Time (Python)", number=3080)
# ---
# Closed
# fujitatomoya
# https://api.github.com/repos/ros2/ros2_documentation/issues/3004
# Issue(title="add documentation about parameter wildcard matching", number=3004)
# ---
# Closed
# ihasdapie
# https://api.github.com/repos/ros2/ros2_documentation/issues/2981
# Issue(title="Service Introspection Documentation and Tutorial", number=2981)
# ---
# Closed
# SanderVanDijk-StreetDrone
# https://api.github.com/repos/ros2/ros2_documentation/issues/2979
# Issue(title="Documentation on parameter callbacks is unclear about how to use 'on_parameter_event'", number=2979)
# ---
# OPEN
# Fildo7525
# https://api.github.com/repos/ros2/ros2_documentation/issues/2944
# Issue(title="Autocompletion in zsh failes", number=2944)
# ---
# Closed
# CodinGeoR
# https://api.github.com/repos/ros2/ros2_documentation/issues/2935
# Issue(title="tf2 timeout python tutorial references code that doesn't exist", number=2935)
# ---
# Closed
# ijnek
# https://api.github.com/repos/ros2/ros2_documentation/issues/2892
# Issue(title="example packages are already built in underlay workspaces", number=2892)
# ---
# Closed
# ihasdapie
# https://api.github.com/repos/ros2/ros2_documentation/issues/2866
# Issue(title="Links on humble About-Client-Interfaces.html point to foxy docs", number=2866)
# ---
# Closed
# Interpause
# https://api.github.com/repos/ros2/ros2_documentation/issues/2801
# Issue(title="[Tutorial] Using ROS Index", number=2801)
# ---
# Closed
# fujitatomoya
# https://api.github.com/repos/ros2/ros2_documentation/issues/2444
# Issue(title="Use permalink instead of copy&paste the source code in documents", number=2444)
# ---
# Closed
# Levels31
# https://api.github.com/repos/ros2/ros2_documentation/issues/2230
# Issue(title="macOS install instructions on foxy", number=2230)
# ---
# Closed
# jonathanTIE
# https://api.github.com/repos/ros2/ros2_documentation/issues/1787
# Issue(title="Windows 10 Installation - add a link to Microsoft IoT RosOnWindows instructions", number=1787)
# ---
# Closed
# Markland01
# https://api.github.com/repos/ros2/ros2_documentation/issues/1778
# Issue(title="Ros2 Foxy Turtle Tutorial qt missing?", number=1778)
# ---
# Closed
# DLu
# https://api.github.com/repos/ros2/ros2_documentation/issues/1700
# Issue(title="Pluginlib Tutorial", number=1700)
# ---
# Closed
# fujitatomoya
# https://api.github.com/repos/ros2/ros2_documentation/issues/1458
# Issue(title="Tutorial: how to make meta-package", number=1458)
# ---
# OPEN
# simutisernestas
# https://api.github.com/repos/ros2/ros2_documentation/issues/1441
# Issue(title="ROS 2 Testing documentation", number=1441)
# ---
# Closed
# clalancette
# https://api.github.com/repos/ros2/ros2_documentation/issues/1169
# Issue(title="Revamp and split the "Features Status" page per distribution", number=1169)
# ---
# Closed
# KvE-sax
# https://api.github.com/repos/ros2/ros2_documentation/issues/897
# Issue(title="Update logger documentation", number=897)
# ---
# Closed
# ActivePeter
# https://api.github.com/repos/ros2/ros2_documentation/issues/881
# Issue(title="Failed to load entry point 'pub': librclpy_common.so: cannot open shared object file: No such file or directory", number=881)
# ---
# Closed
# maryaB-osr
# https://api.github.com/repos/ros2/ros2_documentation/issues/596
# Issue(title="Add a documentation section to Contributing guides", number=596)
# ---
# Closed
# maryaB-osr
# https://api.github.com/repos/ros2/ros2_documentation/issues/585
# Issue(title="Add additional method of declaration to parameters tutorial", number=585)
# ---
# OPEN
# deb0ch
# https://api.github.com/repos/ros2/ros2_documentation/issues/569
# Issue(title="Using the correct QoS profile to subscribe to an existing topic", number=569)
# ---
